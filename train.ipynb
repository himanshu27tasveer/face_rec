# %% [markdown]
# <a href="https://colab.research.google.com/github/himanshu27tasveer/face_rec/blob/main/train.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# %tensorflow_version 1.x
# Out:
# TensorFlow 1.x selected.

# %%
import tensorflow
print(tensorflow.__version__)
# Out:
# 1.15.2

# %%
! unzip /content/drive/MyDrive/CASIA-Aligned-Mask.zip
# Out:
# Streaming output truncated to the last 5000 lines.
#   inflating: content/CASIA-Aligned-Mask/0005095/71_0.png
#   inflating: content/CASIA-Aligned-Mask/0005095/19_0.png
#   inflating: content/CASIA-Aligned-Mask/0005095/28_0.png
#   inflating: content/CASIA-Aligned-Mask/0005095/97_0.png
#   inflating: content/CASIA-Aligned-Mask/0005095/100_0.png
#   inflating: content/CASIA-Aligned-Mask/0005095/87_0.png
#   inflating: content/CASIA-Aligned-Mask/0005095/99_0.png
#   inflating: content/CASIA-Aligned-Mask/0005095/34_0.png
#   inflating: content/CASIA-Aligned-Mask/0005095/15_0.png
#   inflating: content/CASIA-Aligned-Mask/0005095/59_0.png
#   inflating: content/CASIA-Aligned-Mask/0005095/35_0.png
#   inflating: content/CASIA-Aligned-Mask/0005095/119_0.png
#   inflating: content/CASIA-Aligned-Mask/0005095/20_0.png
#   inflating: content/CASIA-Aligned-Mask/0005095/14_0.png
#   inflating: content/CASIA-Aligned-Mask/0005095/91_0.png
#    creating: content/CASIA-Aligned-Mask/0124079/
#   inflating: content/CASIA-Aligned-Mask/0124079/12_0.png
#   inflating: content/CASIA-Aligned-Mask/0124079/8_0.png
#   inflating: content/CASIA-Aligned-Mask/0124079/17_0.png
#   inflating: content/CASIA-Aligned-Mask/0124079/16_0.png
#   inflating: content/CASIA-Aligned-Mask/0124079/9_0.png
#   inflating: content/CASIA-Aligned-Mask/0124079/6_0.png
#   inflating: content/CASIA-Aligned-Mask/0124079/10_0.png
#   inflating: content/CASIA-Aligned-Mask/0124079/4_0.png
#   inflating: content/CASIA-Aligned-Mask/0124079/0_0.png
#   inflating: content/CASIA-Aligned-Mask/0124079/13_0.png
#   inflating: content/CASIA-Aligned-Mask/0124079/3_0.png
#   inflating: content/CASIA-Aligned-Mask/0124079/11_0.png
#   inflating: content/CASIA-Aligned-Mask/0124079/14_0.png
#    creating: content/CASIA-Aligned-Mask/0707899/
#   inflating: content/CASIA-Aligned-Mask/0707899/39_0.png
#   inflating: content/CASIA-Aligned-Mask/0707899/12_0.png
#   inflating: content/CASIA-Aligned-Mask/0707899/33_0.png
#   inflating: content/CASIA-Aligned-Mask/0707899/8_0.png
#   inflating: content/CASIA-Aligned-Mask/0707899/2_0.png
#   inflating: content/CASIA-Aligned-Mask/0707899/17_0.png
#   inflating: content/CASIA-Aligned-Mask/0707899/30_0.png
#   inflating: content/CASIA-Aligned-Mask/0707899/38_0.png
#   inflating: content/CASIA-Aligned-Mask/0707899/40_0.png
#   inflating: content/CASIA-Aligned-Mask/0707899/9_0.png
#   inflating: content/CASIA-Aligned-Mask/0707899/21_0.png
#   inflating: content/CASIA-Aligned-Mask/0707899/6_0.png
#   inflating: content/CASIA-Aligned-Mask/0707899/31_0.png
#   inflating: content/CASIA-Aligned-Mask/0707899/29_0.png
#   inflating: content/CASIA-Aligned-Mask/0707899/10_0.png
#   inflating: content/CASIA-Aligned-Mask/0707899/23_0.png
#   inflating: content/CASIA-Aligned-Mask/0707899/27_0.png
#   inflating: content/CASIA-Aligned-Mask/0707899/24_0.png
#   inflating: content/CASIA-Aligned-Mask/0707899/41_0.png
#   inflating: content/CASIA-Aligned-Mask/0707899/36_0.png
#   inflating: content/CASIA-Aligned-Mask/0707899/4_0.png
#   inflating: content/CASIA-Aligned-Mask/0707899/13_0.png
#   inflating: content/CASIA-Aligned-Mask/0707899/5_0.png
#   inflating: content/CASIA-Aligned-Mask/0707899/3_0.png
#   inflating: content/CASIA-Aligned-Mask/0707899/19_0.png
#   inflating: content/CASIA-Aligned-Mask/0707899/28_0.png
#   inflating: content/CASIA-Aligned-Mask/0707899/34_0.png
#   inflating: content/CASIA-Aligned-Mask/0707899/35_0.png
#   inflating: content/CASIA-Aligned-Mask/0707899/37_0.png
#   inflating: content/CASIA-Aligned-Mask/0707899/20_0.png
#    creating: content/CASIA-Aligned-Mask/0741893/
#   inflating: content/CASIA-Aligned-Mask/0741893/8_0.png
#   inflating: content/CASIA-Aligned-Mask/0741893/2_0.png
#   inflating: content/CASIA-Aligned-Mask/0741893/16_0.png
#   inflating: content/CASIA-Aligned-Mask/0741893/6_0.png
#   inflating: content/CASIA-Aligned-Mask/0741893/7_0.png
#   inflating: content/CASIA-Aligned-Mask/0741893/0_0.png
#   inflating: content/CASIA-Aligned-Mask/0741893/13_0.png
#   inflating: content/CASIA-Aligned-Mask/0741893/5_0.png
#   inflating: content/CASIA-Aligned-Mask/0741893/3_0.png
#   inflating: content/CASIA-Aligned-Mask/0741893/11_0.png
#   inflating: content/CASIA-Aligned-Mask/0741893/15_0.png
#   inflating: content/CASIA-Aligned-Mask/0741893/14_0.png
#    creating: content/CASIA-Aligned-Mask/0734985/
#   inflating: content/CASIA-Aligned-Mask/0734985/42_0.png
#   inflating: content/CASIA-Aligned-Mask/0734985/39_0.png
#   inflating: content/CASIA-Aligned-Mask/0734985/22_0.png
#   inflating: content/CASIA-Aligned-Mask/0734985/25_0.png
#   inflating: content/CASIA-Aligned-Mask/0734985/12_0.png
#   inflating: content/CASIA-Aligned-Mask/0734985/33_0.png
#   inflating: content/CASIA-Aligned-Mask/0734985/8_0.png
#   inflating: content/CASIA-Aligned-Mask/0734985/26_0.png
#   inflating: content/CASIA-Aligned-Mask/0734985/17_0.png
#   inflating: content/CASIA-Aligned-Mask/0734985/30_0.png
#   inflating: content/CASIA-Aligned-Mask/0734985/38_0.png
#   inflating: content/CASIA-Aligned-Mask/0734985/16_0.png
#   inflating: content/CASIA-Aligned-Mask/0734985/51_0.png
#   inflating: content/CASIA-Aligned-Mask/0734985/9_0.png
#   inflating: content/CASIA-Aligned-Mask/0734985/49_0.png
#   inflating: content/CASIA-Aligned-Mask/0734985/21_0.png
#   inflating: content/CASIA-Aligned-Mask/0734985/52_0.png
#   inflating: content/CASIA-Aligned-Mask/0734985/6_0.png
#   inflating: content/CASIA-Aligned-Mask/0734985/31_0.png
#   inflating: content/CASIA-Aligned-Mask/0734985/45_0.png
#   inflating: content/CASIA-Aligned-Mask/0734985/29_0.png
#   inflating: content/CASIA-Aligned-Mask/0734985/1_0.png
#   inflating: content/CASIA-Aligned-Mask/0734985/18_0.png
#   inflating: content/CASIA-Aligned-Mask/0734985/27_0.png
#   inflating: content/CASIA-Aligned-Mask/0734985/55_0.png
#   inflating: content/CASIA-Aligned-Mask/0734985/41_0.png
#   inflating: content/CASIA-Aligned-Mask/0734985/36_0.png
#   inflating: content/CASIA-Aligned-Mask/0734985/4_0.png
#   inflating: content/CASIA-Aligned-Mask/0734985/50_0.png
#   inflating: content/CASIA-Aligned-Mask/0734985/48_0.png
#   inflating: content/CASIA-Aligned-Mask/0734985/3_0.png
#   inflating: content/CASIA-Aligned-Mask/0734985/11_0.png
#   inflating: content/CASIA-Aligned-Mask/0734985/19_0.png
#   inflating: content/CASIA-Aligned-Mask/0734985/28_0.png
#   inflating: content/CASIA-Aligned-Mask/0734985/34_0.png
#   inflating: content/CASIA-Aligned-Mask/0734985/15_0.png
#   inflating: content/CASIA-Aligned-Mask/0734985/35_0.png
#   inflating: content/CASIA-Aligned-Mask/0734985/37_0.png
#   inflating: content/CASIA-Aligned-Mask/0734985/20_0.png
#   inflating: content/CASIA-Aligned-Mask/0734985/14_0.png
#    creating: content/CASIA-Aligned-Mask/0306201/
#   inflating: content/CASIA-Aligned-Mask/0306201/42_0.png
#   inflating: content/CASIA-Aligned-Mask/0306201/39_0.png
#   inflating: content/CASIA-Aligned-Mask/0306201/66_0.png
#   inflating: content/CASIA-Aligned-Mask/0306201/79_0.png
#   inflating: content/CASIA-Aligned-Mask/0306201/84_0.png
#   inflating: content/CASIA-Aligned-Mask/0306201/83_0.png
#   inflating: content/CASIA-Aligned-Mask/0306201/95_0.png
#   inflating: content/CASIA-Aligned-Mask/0306201/115_0.png
#   inflating: content/CASIA-Aligned-Mask/0306201/58_0.png
#   inflating: content/CASIA-Aligned-Mask/0306201/74_0.png
#   inflating: content/CASIA-Aligned-Mask/0306201/75_0.png
#   inflating: content/CASIA-Aligned-Mask/0306201/22_0.png
#   inflating: content/CASIA-Aligned-Mask/0306201/25_0.png
#   inflating: content/CASIA-Aligned-Mask/0306201/69_0.png
#   inflating: content/CASIA-Aligned-Mask/0306201/33_0.png
#   inflating: content/CASIA-Aligned-Mask/0306201/92_0.png
#   inflating: content/CASIA-Aligned-Mask/0306201/78_0.png
#   inflating: content/CASIA-Aligned-Mask/0306201/94_0.png
#   inflating: content/CASIA-Aligned-Mask/0306201/8_0.png
#   inflating: content/CASIA-Aligned-Mask/0306201/56_0.png
#   inflating: content/CASIA-Aligned-Mask/0306201/2_0.png
#   inflating: content/CASIA-Aligned-Mask/0306201/26_0.png
#   inflating: content/CASIA-Aligned-Mask/0306201/103_0.png
#   inflating: content/CASIA-Aligned-Mask/0306201/54_0.png
#   inflating: content/CASIA-Aligned-Mask/0306201/30_0.png
#   inflating: content/CASIA-Aligned-Mask/0306201/114_0.png
#   inflating: content/CASIA-Aligned-Mask/0306201/98_0.png
#   inflating: content/CASIA-Aligned-Mask/0306201/38_0.png
#   inflating: content/CASIA-Aligned-Mask/0306201/82_0.png
#   inflating: content/CASIA-Aligned-Mask/0306201/105_0.png
#   inflating: content/CASIA-Aligned-Mask/0306201/16_0.png
#   inflating: content/CASIA-Aligned-Mask/0306201/89_0.png
#   inflating: content/CASIA-Aligned-Mask/0306201/104_0.png
#   inflating: content/CASIA-Aligned-Mask/0306201/40_0.png
#   inflating: content/CASIA-Aligned-Mask/0306201/96_0.png
#   inflating: content/CASIA-Aligned-Mask/0306201/88_0.png
#   inflating: content/CASIA-Aligned-Mask/0306201/110_0.png
#   inflating: content/CASIA-Aligned-Mask/0306201/61_0.png
#   inflating: content/CASIA-Aligned-Mask/0306201/65_0.png
#   inflating: content/CASIA-Aligned-Mask/0306201/93_0.png
#   inflating: content/CASIA-Aligned-Mask/0306201/90_0.png
#   inflating: content/CASIA-Aligned-Mask/0306201/21_0.png
#   inflating: content/CASIA-Aligned-Mask/0306201/80_0.png
#   inflating: content/CASIA-Aligned-Mask/0306201/60_0.png
#   inflating: content/CASIA-Aligned-Mask/0306201/52_0.png
#   inflating: content/CASIA-Aligned-Mask/0306201/6_0.png
#   inflating: content/CASIA-Aligned-Mask/0306201/31_0.png
#   inflating: content/CASIA-Aligned-Mask/0306201/29_0.png
#   inflating: content/CASIA-Aligned-Mask/0306201/7_0.png
#   inflating: content/CASIA-Aligned-Mask/0306201/32_0.png
#   inflating: content/CASIA-Aligned-Mask/0306201/102_0.png
#   inflating: content/CASIA-Aligned-Mask/0306201/106_0.png
#   inflating: content/CASIA-Aligned-Mask/0306201/76_0.png
#   inflating: content/CASIA-Aligned-Mask/0306201/108_0.png
#   inflating: content/CASIA-Aligned-Mask/0306201/10_0.png
#   inflating: content/CASIA-Aligned-Mask/0306201/18_0.png
#   inflating: content/CASIA-Aligned-Mask/0306201/67_0.png
#   inflating: content/CASIA-Aligned-Mask/0306201/23_0.png
#   inflating: content/CASIA-Aligned-Mask/0306201/27_0.png
#   inflating: content/CASIA-Aligned-Mask/0306201/111_0.png
#   inflating: content/CASIA-Aligned-Mask/0306201/81_0.png
#   inflating: content/CASIA-Aligned-Mask/0306201/55_0.png
#   inflating: content/CASIA-Aligned-Mask/0306201/101_0.png
#   inflating: content/CASIA-Aligned-Mask/0306201/24_0.png
#   inflating: content/CASIA-Aligned-Mask/0306201/41_0.png
#   inflating: content/CASIA-Aligned-Mask/0306201/64_0.png
#   inflating: content/CASIA-Aligned-Mask/0306201/36_0.png
#   inflating: content/CASIA-Aligned-Mask/0306201/4_0.png
#   inflating: content/CASIA-Aligned-Mask/0306201/77_0.png
#   inflating: content/CASIA-Aligned-Mask/0306201/68_0.png
#   inflating: content/CASIA-Aligned-Mask/0306201/85_0.png
#   inflating: content/CASIA-Aligned-Mask/0306201/13_0.png
#   inflating: content/CASIA-Aligned-Mask/0306201/62_0.png
#   inflating: content/CASIA-Aligned-Mask/0306201/48_0.png
#   inflating: content/CASIA-Aligned-Mask/0306201/5_0.png
#   inflating: content/CASIA-Aligned-Mask/0306201/3_0.png
#   inflating: content/CASIA-Aligned-Mask/0306201/11_0.png
#   inflating: content/CASIA-Aligned-Mask/0306201/71_0.png
#   inflating: content/CASIA-Aligned-Mask/0306201/19_0.png
#   inflating: content/CASIA-Aligned-Mask/0306201/28_0.png
#   inflating: content/CASIA-Aligned-Mask/0306201/97_0.png
#   inflating: content/CASIA-Aligned-Mask/0306201/100_0.png
#   inflating: content/CASIA-Aligned-Mask/0306201/87_0.png
#   inflating: content/CASIA-Aligned-Mask/0306201/99_0.png
#   inflating: content/CASIA-Aligned-Mask/0306201/86_0.png
#   inflating: content/CASIA-Aligned-Mask/0306201/34_0.png
#   inflating: content/CASIA-Aligned-Mask/0306201/59_0.png
#   inflating: content/CASIA-Aligned-Mask/0306201/37_0.png
#   inflating: content/CASIA-Aligned-Mask/0306201/20_0.png
#   inflating: content/CASIA-Aligned-Mask/0306201/14_0.png
#   inflating: content/CASIA-Aligned-Mask/0306201/46_0.png
#   inflating: content/CASIA-Aligned-Mask/0306201/91_0.png
#    creating: content/CASIA-Aligned-Mask/0432428/
#   inflating: content/CASIA-Aligned-Mask/0432428/2_0.png
#   inflating: content/CASIA-Aligned-Mask/0432428/1_0.png
#   inflating: content/CASIA-Aligned-Mask/0432428/3_0.png
#    creating: content/CASIA-Aligned-Mask/0000893/
#   inflating: content/CASIA-Aligned-Mask/0000893/42_0.png
#   inflating: content/CASIA-Aligned-Mask/0000893/39_0.png
#   inflating: content/CASIA-Aligned-Mask/0000893/22_0.png
#   inflating: content/CASIA-Aligned-Mask/0000893/25_0.png
#   inflating: content/CASIA-Aligned-Mask/0000893/12_0.png
#   inflating: content/CASIA-Aligned-Mask/0000893/8_0.png
#   inflating: content/CASIA-Aligned-Mask/0000893/2_0.png
#   inflating: content/CASIA-Aligned-Mask/0000893/26_0.png
#   inflating: content/CASIA-Aligned-Mask/0000893/17_0.png
#   inflating: content/CASIA-Aligned-Mask/0000893/30_0.png
#   inflating: content/CASIA-Aligned-Mask/0000893/16_0.png
#   inflating: content/CASIA-Aligned-Mask/0000893/40_0.png
#   inflating: content/CASIA-Aligned-Mask/0000893/9_0.png
#   inflating: content/CASIA-Aligned-Mask/0000893/21_0.png
#   inflating: content/CASIA-Aligned-Mask/0000893/6_0.png
#   inflating: content/CASIA-Aligned-Mask/0000893/31_0.png
#   inflating: content/CASIA-Aligned-Mask/0000893/29_0.png
#   inflating: content/CASIA-Aligned-Mask/0000893/43_0.png
#   inflating: content/CASIA-Aligned-Mask/0000893/1_0.png
#   inflating: content/CASIA-Aligned-Mask/0000893/32_0.png
#   inflating: content/CASIA-Aligned-Mask/0000893/44_0.png
#   inflating: content/CASIA-Aligned-Mask/0000893/10_0.png
#   inflating: content/CASIA-Aligned-Mask/0000893/18_0.png
#   inflating: content/CASIA-Aligned-Mask/0000893/23_0.png
#   inflating: content/CASIA-Aligned-Mask/0000893/24_0.png
#   inflating: content/CASIA-Aligned-Mask/0000893/41_0.png
#   inflating: content/CASIA-Aligned-Mask/0000893/36_0.png
#   inflating: content/CASIA-Aligned-Mask/0000893/4_0.png
#   inflating: content/CASIA-Aligned-Mask/0000893/0_0.png
#   inflating: content/CASIA-Aligned-Mask/0000893/3_0.png
#   inflating: content/CASIA-Aligned-Mask/0000893/19_0.png
#   inflating: content/CASIA-Aligned-Mask/0000893/34_0.png
#   inflating: content/CASIA-Aligned-Mask/0000893/15_0.png
#   inflating: content/CASIA-Aligned-Mask/0000893/37_0.png
#   inflating: content/CASIA-Aligned-Mask/0000893/14_0.png
#   inflating: content/CASIA-Aligned-Mask/0000893/46_0.png
#    creating: content/CASIA-Aligned-Mask/0874618/
#   inflating: content/CASIA-Aligned-Mask/0874618/22_0.png
#   inflating: content/CASIA-Aligned-Mask/0874618/12_0.png
#   inflating: content/CASIA-Aligned-Mask/0874618/2_0.png
#   inflating: content/CASIA-Aligned-Mask/0874618/17_0.png
#   inflating: content/CASIA-Aligned-Mask/0874618/16_0.png
#   inflating: content/CASIA-Aligned-Mask/0874618/9_0.png
#   inflating: content/CASIA-Aligned-Mask/0874618/21_0.png
#   inflating: content/CASIA-Aligned-Mask/0874618/1_0.png
#   inflating: content/CASIA-Aligned-Mask/0874618/7_0.png
#   inflating: content/CASIA-Aligned-Mask/0874618/10_0.png
#   inflating: content/CASIA-Aligned-Mask/0874618/18_0.png
#   inflating: content/CASIA-Aligned-Mask/0874618/23_0.png
#   inflating: content/CASIA-Aligned-Mask/0874618/24_0.png
#   inflating: content/CASIA-Aligned-Mask/0874618/4_0.png
#   inflating: content/CASIA-Aligned-Mask/0874618/0_0.png
#   inflating: content/CASIA-Aligned-Mask/0874618/13_0.png
#   inflating: content/CASIA-Aligned-Mask/0874618/5_0.png
#   inflating: content/CASIA-Aligned-Mask/0874618/11_0.png
#   inflating: content/CASIA-Aligned-Mask/0874618/19_0.png
#   inflating: content/CASIA-Aligned-Mask/0874618/15_0.png
#   inflating: content/CASIA-Aligned-Mask/0874618/20_0.png
#    creating: content/CASIA-Aligned-Mask/0250659/
#   inflating: content/CASIA-Aligned-Mask/0250659/8_0.png
#   inflating: content/CASIA-Aligned-Mask/0250659/9_0.png
#   inflating: content/CASIA-Aligned-Mask/0250659/6_0.png
#   inflating: content/CASIA-Aligned-Mask/0250659/1_0.png
#   inflating: content/CASIA-Aligned-Mask/0250659/7_0.png
#   inflating: content/CASIA-Aligned-Mask/0250659/10_0.png
#   inflating: content/CASIA-Aligned-Mask/0250659/4_0.png
#   inflating: content/CASIA-Aligned-Mask/0250659/5_0.png
#   inflating: content/CASIA-Aligned-Mask/0250659/11_0.png
#   inflating: content/CASIA-Aligned-Mask/0250659/14_0.png
#    creating: content/CASIA-Aligned-Mask/0378245/
#   inflating: content/CASIA-Aligned-Mask/0378245/239_0.png
#   inflating: content/CASIA-Aligned-Mask/0378245/42_0.png
#   inflating: content/CASIA-Aligned-Mask/0378245/121_0.png
#   inflating: content/CASIA-Aligned-Mask/0378245/176_0.png
#   inflating: content/CASIA-Aligned-Mask/0378245/134_0.png
#   inflating: content/CASIA-Aligned-Mask/0378245/157_0.png
#   inflating: content/CASIA-Aligned-Mask/0378245/125_0.png
#   inflating: content/CASIA-Aligned-Mask/0378245/133_0.png
#   inflating: content/CASIA-Aligned-Mask/0378245/217_0.png
#   inflating: content/CASIA-Aligned-Mask/0378245/181_0.png
#   inflating: content/CASIA-Aligned-Mask/0378245/206_0.png
#   inflating: content/CASIA-Aligned-Mask/0378245/79_0.png
#   inflating: content/CASIA-Aligned-Mask/0378245/167_0.png
#   inflating: content/CASIA-Aligned-Mask/0378245/47_0.png
#   inflating: content/CASIA-Aligned-Mask/0378245/83_0.png
#   inflating: content/CASIA-Aligned-Mask/0378245/137_0.png
#   inflating: content/CASIA-Aligned-Mask/0378245/189_0.png
#   inflating: content/CASIA-Aligned-Mask/0378245/95_0.png
#   inflating: content/CASIA-Aligned-Mask/0378245/260_0.png
#   inflating: content/CASIA-Aligned-Mask/0378245/201_0.png
#   inflating: content/CASIA-Aligned-Mask/0378245/237_0.png
#   inflating: content/CASIA-Aligned-Mask/0378245/115_0.png
#   inflating: content/CASIA-Aligned-Mask/0378245/243_0.png
#   inflating: content/CASIA-Aligned-Mask/0378245/158_0.png
#   inflating: content/CASIA-Aligned-Mask/0378245/73_0.png
#   inflating: content/CASIA-Aligned-Mask/0378245/58_0.png
#   inflating: content/CASIA-Aligned-Mask/0378245/238_0.png
#   inflating: content/CASIA-Aligned-Mask/0378245/154_0.png
#   inflating: content/CASIA-Aligned-Mask/0378245/192_0.png
#   inflating: content/CASIA-Aligned-Mask/0378245/74_0.png
#   inflating: content/CASIA-Aligned-Mask/0378245/75_0.png
#   inflating: content/CASIA-Aligned-Mask/0378245/113_0.png
#   inflating: content/CASIA-Aligned-Mask/0378245/118_0.png
#   inflating: content/CASIA-Aligned-Mask/0378245/22_0.png
#   inflating: content/CASIA-Aligned-Mask/0378245/265_0.png
#   inflating: content/CASIA-Aligned-Mask/0378245/123_0.png
#   inflating: content/CASIA-Aligned-Mask/0378245/253_0.png
#   inflating: content/CASIA-Aligned-Mask/0378245/25_0.png
#   inflating: content/CASIA-Aligned-Mask/0378245/69_0.png
#   inflating: content/CASIA-Aligned-Mask/0378245/70_0.png
#   inflating: content/CASIA-Aligned-Mask/0378245/112_0.png
#   inflating: content/CASIA-Aligned-Mask/0378245/128_0.png
#   inflating: content/CASIA-Aligned-Mask/0378245/12_0.png
#   inflating: content/CASIA-Aligned-Mask/0378245/33_0.png
#   inflating: content/CASIA-Aligned-Mask/0378245/92_0.png
#   inflating: content/CASIA-Aligned-Mask/0378245/78_0.png
#   inflating: content/CASIA-Aligned-Mask/0378245/163_0.png
#   inflating: content/CASIA-Aligned-Mask/0378245/8_0.png
#   inflating: content/CASIA-Aligned-Mask/0378245/56_0.png
#   inflating: content/CASIA-Aligned-Mask/0378245/2_0.png
#   inflating: content/CASIA-Aligned-Mask/0378245/233_0.png
#   inflating: content/CASIA-Aligned-Mask/0378245/268_0.png
#   inflating: content/CASIA-Aligned-Mask/0378245/26_0.png
#   inflating: content/CASIA-Aligned-Mask/0378245/271_0.png
#   inflating: content/CASIA-Aligned-Mask/0378245/198_0.png
#   inflating: content/CASIA-Aligned-Mask/0378245/103_0.png
#   inflating: content/CASIA-Aligned-Mask/0378245/197_0.png
#   inflating: content/CASIA-Aligned-Mask/0378245/17_0.png
#   inflating: content/CASIA-Aligned-Mask/0378245/54_0.png
#   inflating: content/CASIA-Aligned-Mask/0378245/156_0.png
#   inflating: content/CASIA-Aligned-Mask/0378245/254_0.png
#   inflating: content/CASIA-Aligned-Mask/0378245/148_0.png
#   inflating: content/CASIA-Aligned-Mask/0378245/240_0.png
#   inflating: content/CASIA-Aligned-Mask/0378245/250_0.png
#   inflating: content/CASIA-Aligned-Mask/0378245/114_0.png
#   inflating: content/CASIA-Aligned-Mask/0378245/168_0.png
#   inflating: content/CASIA-Aligned-Mask/0378245/213_0.png
#   inflating: content/CASIA-Aligned-Mask/0378245/263_0.png
#   inflating: content/CASIA-Aligned-Mask/0378245/82_0.png
#   inflating: content/CASIA-Aligned-Mask/0378245/105_0.png
#   inflating: content/CASIA-Aligned-Mask/0378245/191_0.png
#   inflating: content/CASIA-Aligned-Mask/0378245/236_0.png
#   inflating: content/CASIA-Aligned-Mask/0378245/266_0.png
#   inflating: content/CASIA-Aligned-Mask/0378245/142_0.png
#   inflating: content/CASIA-Aligned-Mask/0378245/141_0.png
#   inflating: content/CASIA-Aligned-Mask/0378245/145_0.png
#   inflating: content/CASIA-Aligned-Mask/0378245/104_0.png
#   inflating: content/CASIA-Aligned-Mask/0378245/40_0.png
#   inflating: content/CASIA-Aligned-Mask/0378245/183_0.png
#   inflating: content/CASIA-Aligned-Mask/0378245/251_0.png
#   inflating: content/CASIA-Aligned-Mask/0378245/178_0.png
#   inflating: content/CASIA-Aligned-Mask/0378245/180_0.png
#   inflating: content/CASIA-Aligned-Mask/0378245/242_0.png
#   inflating: content/CASIA-Aligned-Mask/0378245/273_0.png
#   inflating: content/CASIA-Aligned-Mask/0378245/160_0.png
#   inflating: content/CASIA-Aligned-Mask/0378245/232_0.png
#   inflating: content/CASIA-Aligned-Mask/0378245/109_0.png
#   inflating: content/CASIA-Aligned-Mask/0378245/53_0.png
#   inflating: content/CASIA-Aligned-Mask/0378245/143_0.png
#   inflating: content/CASIA-Aligned-Mask/0378245/221_0.png
#   inflating: content/CASIA-Aligned-Mask/0378245/88_0.png
#   inflating: content/CASIA-Aligned-Mask/0378245/110_0.png
#   inflating: content/CASIA-Aligned-Mask/0378245/61_0.png
#   inflating: content/CASIA-Aligned-Mask/0378245/195_0.png
#   inflating: content/CASIA-Aligned-Mask/0378245/175_0.png
#   inflating: content/CASIA-Aligned-Mask/0378245/229_0.png
#   inflating: content/CASIA-Aligned-Mask/0378245/164_0.png
#   inflating: content/CASIA-Aligned-Mask/0378245/65_0.png
#   inflating: content/CASIA-Aligned-Mask/0378245/173_0.png
#   inflating: content/CASIA-Aligned-Mask/0378245/215_0.png
#   inflating: content/CASIA-Aligned-Mask/0378245/60_0.png
#   inflating: content/CASIA-Aligned-Mask/0378245/52_0.png
#   inflating: content/CASIA-Aligned-Mask/0378245/205_0.png
#   inflating: content/CASIA-Aligned-Mask/0378245/31_0.png
#   inflating: content/CASIA-Aligned-Mask/0378245/146_0.png
#   inflating: content/CASIA-Aligned-Mask/0378245/182_0.png
#   inflating: content/CASIA-Aligned-Mask/0378245/207_0.png
#   inflating: content/CASIA-Aligned-Mask/0378245/196_0.png
#   inflating: content/CASIA-Aligned-Mask/0378245/255_0.png
#   inflating: content/CASIA-Aligned-Mask/0378245/45_0.png
#   inflating: content/CASIA-Aligned-Mask/0378245/29_0.png
#   inflating: content/CASIA-Aligned-Mask/0378245/43_0.png
#   inflating: content/CASIA-Aligned-Mask/0378245/1_0.png
#   inflating: content/CASIA-Aligned-Mask/0378245/126_0.png
#   inflating: content/CASIA-Aligned-Mask/0378245/151_0.png
#   inflating: content/CASIA-Aligned-Mask/0378245/245_0.png
#   inflating: content/CASIA-Aligned-Mask/0378245/7_0.png
#   inflating: content/CASIA-Aligned-Mask/0378245/32_0.png
#   inflating: content/CASIA-Aligned-Mask/0378245/261_0.png
#   inflating: content/CASIA-Aligned-Mask/0378245/249_0.png
#   inflating: content/CASIA-Aligned-Mask/0378245/102_0.png
#   inflating: content/CASIA-Aligned-Mask/0378245/220_0.png
#   inflating: content/CASIA-Aligned-Mask/0378245/234_0.png
#   inflating: content/CASIA-Aligned-Mask/0378245/216_0.png
#   inflating: content/CASIA-Aligned-Mask/0378245/165_0.png
#   inflating: content/CASIA-Aligned-Mask/0378245/76_0.png
#   inflating: content/CASIA-Aligned-Mask/0378245/108_0.png
#   inflating: content/CASIA-Aligned-Mask/0378245/222_0.png
#   inflating: content/CASIA-Aligned-Mask/0378245/44_0.png
#   inflating: content/CASIA-Aligned-Mask/0378245/226_0.png
#   inflating: content/CASIA-Aligned-Mask/0378245/272_0.png
#   inflating: content/CASIA-Aligned-Mask/0378245/204_0.png
#   inflating: content/CASIA-Aligned-Mask/0378245/18_0.png
#   inflating: content/CASIA-Aligned-Mask/0378245/67_0.png
#   inflating: content/CASIA-Aligned-Mask/0378245/23_0.png
#   inflating: content/CASIA-Aligned-Mask/0378245/203_0.png
#   inflating: content/CASIA-Aligned-Mask/0378245/27_0.png
#   inflating: content/CASIA-Aligned-Mask/0378245/171_0.png
#   inflating: content/CASIA-Aligned-Mask/0378245/209_0.png
#   inflating: content/CASIA-Aligned-Mask/0378245/270_0.png
#   inflating: content/CASIA-Aligned-Mask/0378245/127_0.png
#   inflating: content/CASIA-Aligned-Mask/0378245/132_0.png
#   inflating: content/CASIA-Aligned-Mask/0378245/130_0.png
#   inflating: content/CASIA-Aligned-Mask/0378245/55_0.png
#   inflating: content/CASIA-Aligned-Mask/0378245/101_0.png
#   inflating: content/CASIA-Aligned-Mask/0378245/150_0.png
#   inflating: content/CASIA-Aligned-Mask/0378245/24_0.png
#   inflating: content/CASIA-Aligned-Mask/0378245/208_0.png
#   inflating: content/CASIA-Aligned-Mask/0378245/41_0.png
#   inflating: content/CASIA-Aligned-Mask/0378245/64_0.png
#   inflating: content/CASIA-Aligned-Mask/0378245/186_0.png
#   inflating: content/CASIA-Aligned-Mask/0378245/72_0.png
#   inflating: content/CASIA-Aligned-Mask/0378245/219_0.png
#   inflating: content/CASIA-Aligned-Mask/0378245/223_0.png
#   inflating: content/CASIA-Aligned-Mask/0378245/4_0.png
#   inflating: content/CASIA-Aligned-Mask/0378245/77_0.png
#   inflating: content/CASIA-Aligned-Mask/0378245/68_0.png
#   inflating: content/CASIA-Aligned-Mask/0378245/0_0.png
#   inflating: content/CASIA-Aligned-Mask/0378245/85_0.png
#   inflating: content/CASIA-Aligned-Mask/0378245/13_0.png
#   inflating: content/CASIA-Aligned-Mask/0378245/63_0.png
#   inflating: content/CASIA-Aligned-Mask/0378245/247_0.png
#   inflating: content/CASIA-Aligned-Mask/0378245/50_0.png
#   inflating: content/CASIA-Aligned-Mask/0378245/62_0.png
#   inflating: content/CASIA-Aligned-Mask/0378245/262_0.png
#   inflating: content/CASIA-Aligned-Mask/0378245/162_0.png
#   inflating: content/CASIA-Aligned-Mask/0378245/244_0.png
#   inflating: content/CASIA-Aligned-Mask/0378245/48_0.png
#   inflating: content/CASIA-Aligned-Mask/0378245/155_0.png
#   inflating: content/CASIA-Aligned-Mask/0378245/5_0.png
#   inflating: content/CASIA-Aligned-Mask/0378245/3_0.png
#   inflating: content/CASIA-Aligned-Mask/0378245/144_0.png
#   inflating: content/CASIA-Aligned-Mask/0378245/264_0.png
#   inflating: content/CASIA-Aligned-Mask/0378245/11_0.png
#   inflating: content/CASIA-Aligned-Mask/0378245/147_0.png
#   inflating: content/CASIA-Aligned-Mask/0378245/230_0.png
#   inflating: content/CASIA-Aligned-Mask/0378245/140_0.png
#   inflating: content/CASIA-Aligned-Mask/0378245/200_0.png
#   inflating: content/CASIA-Aligned-Mask/0378245/28_0.png
#   inflating: content/CASIA-Aligned-Mask/0378245/97_0.png
#   inflating: content/CASIA-Aligned-Mask/0378245/116_0.png
#   inflating: content/CASIA-Aligned-Mask/0378245/100_0.png
#   inflating: content/CASIA-Aligned-Mask/0378245/185_0.png
#   inflating: content/CASIA-Aligned-Mask/0378245/87_0.png
#   inflating: content/CASIA-Aligned-Mask/0378245/199_0.png
#   inflating: content/CASIA-Aligned-Mask/0378245/190_0.png
#   inflating: content/CASIA-Aligned-Mask/0378245/179_0.png
#   inflating: content/CASIA-Aligned-Mask/0378245/259_0.png
#   inflating: content/CASIA-Aligned-Mask/0378245/57_0.png
#   inflating: content/CASIA-Aligned-Mask/0378245/99_0.png
#   inflating: content/CASIA-Aligned-Mask/0378245/86_0.png
#   inflating: content/CASIA-Aligned-Mask/0378245/15_0.png
#   inflating: content/CASIA-Aligned-Mask/0378245/129_0.png
#   inflating: content/CASIA-Aligned-Mask/0378245/269_0.png
#   inflating: content/CASIA-Aligned-Mask/0378245/35_0.png
#   inflating: content/CASIA-Aligned-Mask/0378245/188_0.png
#   inflating: content/CASIA-Aligned-Mask/0378245/37_0.png
#   inflating: content/CASIA-Aligned-Mask/0378245/228_0.png
#   inflating: content/CASIA-Aligned-Mask/0378245/258_0.png
#   inflating: content/CASIA-Aligned-Mask/0378245/46_0.png
#   inflating: content/CASIA-Aligned-Mask/0378245/117_0.png
#   inflating: content/CASIA-Aligned-Mask/0378245/91_0.png
#    creating: content/CASIA-Aligned-Mask/0046337/
#   inflating: content/CASIA-Aligned-Mask/0046337/22_0.png
#   inflating: content/CASIA-Aligned-Mask/0046337/2_0.png
#   inflating: content/CASIA-Aligned-Mask/0046337/16_0.png
#   inflating: content/CASIA-Aligned-Mask/0046337/9_0.png
#   inflating: content/CASIA-Aligned-Mask/0046337/21_0.png
#   inflating: content/CASIA-Aligned-Mask/0046337/6_0.png
#   inflating: content/CASIA-Aligned-Mask/0046337/18_0.png
#   inflating: content/CASIA-Aligned-Mask/0046337/4_0.png
#   inflating: content/CASIA-Aligned-Mask/0046337/13_0.png
#   inflating: content/CASIA-Aligned-Mask/0046337/3_0.png
#   inflating: content/CASIA-Aligned-Mask/0046337/11_0.png
#   inflating: content/CASIA-Aligned-Mask/0046337/19_0.png
#    creating: content/CASIA-Aligned-Mask/0006684/
#   inflating: content/CASIA-Aligned-Mask/0006684/22_0.png
#   inflating: content/CASIA-Aligned-Mask/0006684/12_0.png
#   inflating: content/CASIA-Aligned-Mask/0006684/2_0.png
#   inflating: content/CASIA-Aligned-Mask/0006684/16_0.png
#   inflating: content/CASIA-Aligned-Mask/0006684/6_0.png
#   inflating: content/CASIA-Aligned-Mask/0006684/1_0.png
#   inflating: content/CASIA-Aligned-Mask/0006684/7_0.png
#   inflating: content/CASIA-Aligned-Mask/0006684/10_0.png
#   inflating: content/CASIA-Aligned-Mask/0006684/18_0.png
#   inflating: content/CASIA-Aligned-Mask/0006684/24_0.png
#   inflating: content/CASIA-Aligned-Mask/0006684/4_0.png
#   inflating: content/CASIA-Aligned-Mask/0006684/0_0.png
#   inflating: content/CASIA-Aligned-Mask/0006684/3_0.png
#   inflating: content/CASIA-Aligned-Mask/0006684/19_0.png
#   inflating: content/CASIA-Aligned-Mask/0006684/15_0.png
#   inflating: content/CASIA-Aligned-Mask/0006684/20_0.png
#   inflating: content/CASIA-Aligned-Mask/0006684/14_0.png
#    creating: content/CASIA-Aligned-Mask/0893965/
#   inflating: content/CASIA-Aligned-Mask/0893965/12_0.png
#   inflating: content/CASIA-Aligned-Mask/0893965/8_0.png
#   inflating: content/CASIA-Aligned-Mask/0893965/2_0.png
#   inflating: content/CASIA-Aligned-Mask/0893965/17_0.png
#   inflating: content/CASIA-Aligned-Mask/0893965/9_0.png
#   inflating: content/CASIA-Aligned-Mask/0893965/21_0.png
#   inflating: content/CASIA-Aligned-Mask/0893965/1_0.png
#   inflating: content/CASIA-Aligned-Mask/0893965/7_0.png
#   inflating: content/CASIA-Aligned-Mask/0893965/10_0.png
#   inflating: content/CASIA-Aligned-Mask/0893965/18_0.png
#   inflating: content/CASIA-Aligned-Mask/0893965/0_0.png
#   inflating: content/CASIA-Aligned-Mask/0893965/13_0.png
#   inflating: content/CASIA-Aligned-Mask/0893965/5_0.png
#   inflating: content/CASIA-Aligned-Mask/0893965/3_0.png
#   inflating: content/CASIA-Aligned-Mask/0893965/11_0.png
#   inflating: content/CASIA-Aligned-Mask/0893965/20_0.png
#   inflating: content/CASIA-Aligned-Mask/0893965/14_0.png
#    creating: content/CASIA-Aligned-Mask/0004897/
#   inflating: content/CASIA-Aligned-Mask/0004897/12_0.png
#   inflating: content/CASIA-Aligned-Mask/0004897/8_0.png
#   inflating: content/CASIA-Aligned-Mask/0004897/2_0.png
#   inflating: content/CASIA-Aligned-Mask/0004897/17_0.png
#   inflating: content/CASIA-Aligned-Mask/0004897/16_0.png
#   inflating: content/CASIA-Aligned-Mask/0004897/9_0.png
#   inflating: content/CASIA-Aligned-Mask/0004897/6_0.png
#   inflating: content/CASIA-Aligned-Mask/0004897/1_0.png
#   inflating: content/CASIA-Aligned-Mask/0004897/7_0.png
#   inflating: content/CASIA-Aligned-Mask/0004897/10_0.png
#   inflating: content/CASIA-Aligned-Mask/0004897/4_0.png
#   inflating: content/CASIA-Aligned-Mask/0004897/0_0.png
#   inflating: content/CASIA-Aligned-Mask/0004897/13_0.png
#   inflating: content/CASIA-Aligned-Mask/0004897/5_0.png
#   inflating: content/CASIA-Aligned-Mask/0004897/3_0.png
#   inflating: content/CASIA-Aligned-Mask/0004897/11_0.png
#   inflating: content/CASIA-Aligned-Mask/0004897/15_0.png
#   inflating: content/CASIA-Aligned-Mask/0004897/14_0.png
#    creating: content/CASIA-Aligned-Mask/0004954/
#   inflating: content/CASIA-Aligned-Mask/0004954/12_0.png
#   inflating: content/CASIA-Aligned-Mask/0004954/8_0.png
#   inflating: content/CASIA-Aligned-Mask/0004954/2_0.png
#   inflating: content/CASIA-Aligned-Mask/0004954/9_0.png
#   inflating: content/CASIA-Aligned-Mask/0004954/6_0.png
#   inflating: content/CASIA-Aligned-Mask/0004954/7_0.png
#   inflating: content/CASIA-Aligned-Mask/0004954/10_0.png
#   inflating: content/CASIA-Aligned-Mask/0004954/4_0.png
#   inflating: content/CASIA-Aligned-Mask/0004954/0_0.png
#   inflating: content/CASIA-Aligned-Mask/0004954/13_0.png
#   inflating: content/CASIA-Aligned-Mask/0004954/5_0.png
#   inflating: content/CASIA-Aligned-Mask/0004954/11_0.png
#   inflating: content/CASIA-Aligned-Mask/0004954/15_0.png
#    creating: content/CASIA-Aligned-Mask/0443824/
#   inflating: content/CASIA-Aligned-Mask/0443824/12_0.png
#   inflating: content/CASIA-Aligned-Mask/0443824/2_0.png
#   inflating: content/CASIA-Aligned-Mask/0443824/6_0.png
#   inflating: content/CASIA-Aligned-Mask/0443824/10_0.png
#   inflating: content/CASIA-Aligned-Mask/0443824/4_0.png
#   inflating: content/CASIA-Aligned-Mask/0443824/13_0.png
#   inflating: content/CASIA-Aligned-Mask/0443824/5_0.png
#   inflating: content/CASIA-Aligned-Mask/0443824/3_0.png
#    creating: content/CASIA-Aligned-Mask/0489476/
#   inflating: content/CASIA-Aligned-Mask/0489476/12_0.png
#   inflating: content/CASIA-Aligned-Mask/0489476/8_0.png
#   inflating: content/CASIA-Aligned-Mask/0489476/2_0.png
#   inflating: content/CASIA-Aligned-Mask/0489476/16_0.png
#   inflating: content/CASIA-Aligned-Mask/0489476/9_0.png
#   inflating: content/CASIA-Aligned-Mask/0489476/6_0.png
#   inflating: content/CASIA-Aligned-Mask/0489476/1_0.png
#   inflating: content/CASIA-Aligned-Mask/0489476/7_0.png
#   inflating: content/CASIA-Aligned-Mask/0489476/10_0.png
#   inflating: content/CASIA-Aligned-Mask/0489476/4_0.png
#   inflating: content/CASIA-Aligned-Mask/0489476/0_0.png
#   inflating: content/CASIA-Aligned-Mask/0489476/13_0.png
#   inflating: content/CASIA-Aligned-Mask/0489476/5_0.png
#   inflating: content/CASIA-Aligned-Mask/0489476/15_0.png
#   inflating: content/CASIA-Aligned-Mask/0489476/14_0.png
#    creating: content/CASIA-Aligned-Mask/0152918/
#   inflating: content/CASIA-Aligned-Mask/0152918/39_0.png
#   inflating: content/CASIA-Aligned-Mask/0152918/22_0.png
#   inflating: content/CASIA-Aligned-Mask/0152918/25_0.png
#   inflating: content/CASIA-Aligned-Mask/0152918/12_0.png
#   inflating: content/CASIA-Aligned-Mask/0152918/33_0.png
#   inflating: content/CASIA-Aligned-Mask/0152918/8_0.png
#   inflating: content/CASIA-Aligned-Mask/0152918/2_0.png
#   inflating: content/CASIA-Aligned-Mask/0152918/26_0.png
#   inflating: content/CASIA-Aligned-Mask/0152918/30_0.png
#   inflating: content/CASIA-Aligned-Mask/0152918/38_0.png
#   inflating: content/CASIA-Aligned-Mask/0152918/16_0.png
#   inflating: content/CASIA-Aligned-Mask/0152918/40_0.png
#   inflating: content/CASIA-Aligned-Mask/0152918/9_0.png
#   inflating: content/CASIA-Aligned-Mask/0152918/6_0.png
#   inflating: content/CASIA-Aligned-Mask/0152918/29_0.png
#   inflating: content/CASIA-Aligned-Mask/0152918/7_0.png
#   inflating: content/CASIA-Aligned-Mask/0152918/10_0.png
#   inflating: content/CASIA-Aligned-Mask/0152918/18_0.png
#   inflating: content/CASIA-Aligned-Mask/0152918/23_0.png
#   inflating: content/CASIA-Aligned-Mask/0152918/27_0.png
#   inflating: content/CASIA-Aligned-Mask/0152918/36_0.png
#   inflating: content/CASIA-Aligned-Mask/0152918/4_0.png
#   inflating: content/CASIA-Aligned-Mask/0152918/0_0.png
#   inflating: content/CASIA-Aligned-Mask/0152918/13_0.png
#   inflating: content/CASIA-Aligned-Mask/0152918/5_0.png
#   inflating: content/CASIA-Aligned-Mask/0152918/3_0.png
#   inflating: content/CASIA-Aligned-Mask/0152918/11_0.png
#   inflating: content/CASIA-Aligned-Mask/0152918/28_0.png
#   inflating: content/CASIA-Aligned-Mask/0152918/34_0.png
#   inflating: content/CASIA-Aligned-Mask/0152918/15_0.png
#   inflating: content/CASIA-Aligned-Mask/0152918/35_0.png
#   inflating: content/CASIA-Aligned-Mask/0152918/37_0.png
#   inflating: content/CASIA-Aligned-Mask/0152918/20_0.png
#   inflating: content/CASIA-Aligned-Mask/0152918/14_0.png
#    creating: content/CASIA-Aligned-Mask/0172558/
#   inflating: content/CASIA-Aligned-Mask/0172558/12_0.png
#   inflating: content/CASIA-Aligned-Mask/0172558/2_0.png
#   inflating: content/CASIA-Aligned-Mask/0172558/17_0.png
#   inflating: content/CASIA-Aligned-Mask/0172558/9_0.png
#   inflating: content/CASIA-Aligned-Mask/0172558/1_0.png
#   inflating: content/CASIA-Aligned-Mask/0172558/7_0.png
#   inflating: content/CASIA-Aligned-Mask/0172558/4_0.png
#   inflating: content/CASIA-Aligned-Mask/0172558/13_0.png
#   inflating: content/CASIA-Aligned-Mask/0172558/5_0.png
#   inflating: content/CASIA-Aligned-Mask/0172558/3_0.png
#   inflating: content/CASIA-Aligned-Mask/0172558/11_0.png
#   inflating: content/CASIA-Aligned-Mask/0172558/19_0.png
#   inflating: content/CASIA-Aligned-Mask/0172558/15_0.png
#   inflating: content/CASIA-Aligned-Mask/0172558/14_0.png
#    creating: content/CASIA-Aligned-Mask/0001496/
#   inflating: content/CASIA-Aligned-Mask/0001496/22_0.png
#   inflating: content/CASIA-Aligned-Mask/0001496/25_0.png
#   inflating: content/CASIA-Aligned-Mask/0001496/8_0.png
#   inflating: content/CASIA-Aligned-Mask/0001496/2_0.png
#   inflating: content/CASIA-Aligned-Mask/0001496/26_0.png
#   inflating: content/CASIA-Aligned-Mask/0001496/17_0.png
#   inflating: content/CASIA-Aligned-Mask/0001496/16_0.png
#   inflating: content/CASIA-Aligned-Mask/0001496/9_0.png
#   inflating: content/CASIA-Aligned-Mask/0001496/21_0.png
#   inflating: content/CASIA-Aligned-Mask/0001496/6_0.png
#   inflating: content/CASIA-Aligned-Mask/0001496/7_0.png
#   inflating: content/CASIA-Aligned-Mask/0001496/10_0.png
#   inflating: content/CASIA-Aligned-Mask/0001496/18_0.png
#   inflating: content/CASIA-Aligned-Mask/0001496/23_0.png
#   inflating: content/CASIA-Aligned-Mask/0001496/27_0.png
#   inflating: content/CASIA-Aligned-Mask/0001496/4_0.png
#   inflating: content/CASIA-Aligned-Mask/0001496/0_0.png
#   inflating: content/CASIA-Aligned-Mask/0001496/13_0.png
#   inflating: content/CASIA-Aligned-Mask/0001496/5_0.png
#   inflating: content/CASIA-Aligned-Mask/0001496/3_0.png
#   inflating: content/CASIA-Aligned-Mask/0001496/11_0.png
#   inflating: content/CASIA-Aligned-Mask/0001496/28_0.png
#   inflating: content/CASIA-Aligned-Mask/0001496/15_0.png
#   inflating: content/CASIA-Aligned-Mask/0001496/20_0.png
#    creating: content/CASIA-Aligned-Mask/0334159/
#   inflating: content/CASIA-Aligned-Mask/0334159/42_0.png
#   inflating: content/CASIA-Aligned-Mask/0334159/121_0.png
#   inflating: content/CASIA-Aligned-Mask/0334159/120_0.png
#   inflating: content/CASIA-Aligned-Mask/0334159/66_0.png
#   inflating: content/CASIA-Aligned-Mask/0334159/47_0.png
#   inflating: content/CASIA-Aligned-Mask/0334159/83_0.png
#   inflating: content/CASIA-Aligned-Mask/0334159/95_0.png
#   inflating: content/CASIA-Aligned-Mask/0334159/58_0.png
#   inflating: content/CASIA-Aligned-Mask/0334159/74_0.png
#   inflating: content/CASIA-Aligned-Mask/0334159/118_0.png
#   inflating: content/CASIA-Aligned-Mask/0334159/22_0.png
#   inflating: content/CASIA-Aligned-Mask/0334159/25_0.png
#   inflating: content/CASIA-Aligned-Mask/0334159/70_0.png
#   inflating: content/CASIA-Aligned-Mask/0334159/78_0.png
#   inflating: content/CASIA-Aligned-Mask/0334159/8_0.png
#   inflating: content/CASIA-Aligned-Mask/0334159/56_0.png
#   inflating: content/CASIA-Aligned-Mask/0334159/103_0.png
#   inflating: content/CASIA-Aligned-Mask/0334159/54_0.png
#   inflating: content/CASIA-Aligned-Mask/0334159/30_0.png
#   inflating: content/CASIA-Aligned-Mask/0334159/98_0.png
#   inflating: content/CASIA-Aligned-Mask/0334159/82_0.png
#   inflating: content/CASIA-Aligned-Mask/0334159/105_0.png
#   inflating: content/CASIA-Aligned-Mask/0334159/16_0.png
#   inflating: content/CASIA-Aligned-Mask/0334159/89_0.png
#   inflating: content/CASIA-Aligned-Mask/0334159/104_0.png
#   inflating: content/CASIA-Aligned-Mask/0334159/51_0.png
#   inflating: content/CASIA-Aligned-Mask/0334159/40_0.png
#   inflating: content/CASIA-Aligned-Mask/0334159/109_0.png
#   inflating: content/CASIA-Aligned-Mask/0334159/96_0.png
#   inflating: content/CASIA-Aligned-Mask/0334159/53_0.png
#   inflating: content/CASIA-Aligned-Mask/0334159/110_0.png
#   inflating: content/CASIA-Aligned-Mask/0334159/61_0.png
#   inflating: content/CASIA-Aligned-Mask/0334159/21_0.png
#   inflating: content/CASIA-Aligned-Mask/0334159/80_0.png
#   inflating: content/CASIA-Aligned-Mask/0334159/60_0.png
#   inflating: content/CASIA-Aligned-Mask/0334159/6_0.png
#   inflating: content/CASIA-Aligned-Mask/0334159/45_0.png
#   inflating: content/CASIA-Aligned-Mask/0334159/29_0.png
#   inflating: content/CASIA-Aligned-Mask/0334159/43_0.png
#   inflating: content/CASIA-Aligned-Mask/0334159/1_0.png
#   inflating: content/CASIA-Aligned-Mask/0334159/126_0.png
#   inflating: content/CASIA-Aligned-Mask/0334159/7_0.png
#   inflating: content/CASIA-Aligned-Mask/0334159/32_0.png
#   inflating: content/CASIA-Aligned-Mask/0334159/102_0.png
#   inflating: content/CASIA-Aligned-Mask/0334159/108_0.png
#   inflating: content/CASIA-Aligned-Mask/0334159/44_0.png
#   inflating: content/CASIA-Aligned-Mask/0334159/10_0.png
#   inflating: content/CASIA-Aligned-Mask/0334159/18_0.png
#   inflating: content/CASIA-Aligned-Mask/0334159/67_0.png
#   inflating: content/CASIA-Aligned-Mask/0334159/23_0.png
#   inflating: content/CASIA-Aligned-Mask/0334159/127_0.png
#   inflating: content/CASIA-Aligned-Mask/0334159/122_0.png
#   inflating: content/CASIA-Aligned-Mask/0334159/132_0.png
#   inflating: content/CASIA-Aligned-Mask/0334159/130_0.png
#   inflating: content/CASIA-Aligned-Mask/0334159/81_0.png
#   inflating: content/CASIA-Aligned-Mask/0334159/55_0.png
#   inflating: content/CASIA-Aligned-Mask/0334159/24_0.png
#   inflating: content/CASIA-Aligned-Mask/0334159/41_0.png
#   inflating: content/CASIA-Aligned-Mask/0334159/36_0.png
#   inflating: content/CASIA-Aligned-Mask/0334159/4_0.png
#   inflating: content/CASIA-Aligned-Mask/0334159/0_0.png
#   inflating: content/CASIA-Aligned-Mask/0334159/13_0.png
#   inflating: content/CASIA-Aligned-Mask/0334159/50_0.png
#   inflating: content/CASIA-Aligned-Mask/0334159/62_0.png
#   inflating: content/CASIA-Aligned-Mask/0334159/48_0.png
#   inflating: content/CASIA-Aligned-Mask/0334159/5_0.png
#   inflating: content/CASIA-Aligned-Mask/0334159/11_0.png
#   inflating: content/CASIA-Aligned-Mask/0334159/19_0.png
#   inflating: content/CASIA-Aligned-Mask/0334159/116_0.png
#   inflating: content/CASIA-Aligned-Mask/0334159/99_0.png
#   inflating: content/CASIA-Aligned-Mask/0334159/34_0.png
#   inflating: content/CASIA-Aligned-Mask/0334159/15_0.png
#   inflating: content/CASIA-Aligned-Mask/0334159/35_0.png
#   inflating: content/CASIA-Aligned-Mask/0334159/119_0.png
#   inflating: content/CASIA-Aligned-Mask/0334159/20_0.png
#   inflating: content/CASIA-Aligned-Mask/0334159/14_0.png
#   inflating: content/CASIA-Aligned-Mask/0334159/46_0.png
#   inflating: content/CASIA-Aligned-Mask/0334159/91_0.png
#    creating: content/CASIA-Aligned-Mask/0663854/
#   inflating: content/CASIA-Aligned-Mask/0663854/16_0.png
#   inflating: content/CASIA-Aligned-Mask/0663854/9_0.png
#   inflating: content/CASIA-Aligned-Mask/0663854/1_0.png
#   inflating: content/CASIA-Aligned-Mask/0663854/10_0.png
#   inflating: content/CASIA-Aligned-Mask/0663854/18_0.png
#   inflating: content/CASIA-Aligned-Mask/0663854/4_0.png
#   inflating: content/CASIA-Aligned-Mask/0663854/5_0.png
#   inflating: content/CASIA-Aligned-Mask/0663854/3_0.png
#   inflating: content/CASIA-Aligned-Mask/0663854/11_0.png
#   inflating: content/CASIA-Aligned-Mask/0663854/19_0.png
#   inflating: content/CASIA-Aligned-Mask/0663854/15_0.png
#   inflating: content/CASIA-Aligned-Mask/0663854/20_0.png
#    creating: content/CASIA-Aligned-Mask/0773884/
#   inflating: content/CASIA-Aligned-Mask/0773884/42_0.png
#   inflating: content/CASIA-Aligned-Mask/0773884/39_0.png
#   inflating: content/CASIA-Aligned-Mask/0773884/22_0.png
#   inflating: content/CASIA-Aligned-Mask/0773884/12_0.png
#   inflating: content/CASIA-Aligned-Mask/0773884/33_0.png
#   inflating: content/CASIA-Aligned-Mask/0773884/8_0.png
#   inflating: content/CASIA-Aligned-Mask/0773884/2_0.png
#   inflating: content/CASIA-Aligned-Mask/0773884/17_0.png
#   inflating: content/CASIA-Aligned-Mask/0773884/30_0.png
#   inflating: content/CASIA-Aligned-Mask/0773884/38_0.png
#   inflating: content/CASIA-Aligned-Mask/0773884/16_0.png
#   inflating: content/CASIA-Aligned-Mask/0773884/40_0.png
#   inflating: content/CASIA-Aligned-Mask/0773884/9_0.png
#   inflating: content/CASIA-Aligned-Mask/0773884/21_0.png
#   inflating: content/CASIA-Aligned-Mask/0773884/6_0.png
#   inflating: content/CASIA-Aligned-Mask/0773884/31_0.png
#   inflating: content/CASIA-Aligned-Mask/0773884/29_0.png
#   inflating: content/CASIA-Aligned-Mask/0773884/43_0.png
#   inflating: content/CASIA-Aligned-Mask/0773884/1_0.png
#   inflating: content/CASIA-Aligned-Mask/0773884/32_0.png
#   inflating: content/CASIA-Aligned-Mask/0773884/27_0.png
#   inflating: content/CASIA-Aligned-Mask/0773884/24_0.png
#   inflating: content/CASIA-Aligned-Mask/0773884/41_0.png
#   inflating: content/CASIA-Aligned-Mask/0773884/4_0.png
#   inflating: content/CASIA-Aligned-Mask/0773884/0_0.png
#   inflating: content/CASIA-Aligned-Mask/0773884/13_0.png
#   inflating: content/CASIA-Aligned-Mask/0773884/5_0.png
#   inflating: content/CASIA-Aligned-Mask/0773884/3_0.png
#   inflating: content/CASIA-Aligned-Mask/0773884/11_0.png
#   inflating: content/CASIA-Aligned-Mask/0773884/19_0.png
#   inflating: content/CASIA-Aligned-Mask/0773884/28_0.png
#   inflating: content/CASIA-Aligned-Mask/0773884/15_0.png
#   inflating: content/CASIA-Aligned-Mask/0773884/37_0.png
#   inflating: content/CASIA-Aligned-Mask/0773884/20_0.png
#    creating: content/CASIA-Aligned-Mask/0631021/
#   inflating: content/CASIA-Aligned-Mask/0631021/12_0.png
#   inflating: content/CASIA-Aligned-Mask/0631021/8_0.png
#   inflating: content/CASIA-Aligned-Mask/0631021/2_0.png
#   inflating: content/CASIA-Aligned-Mask/0631021/26_0.png
#   inflating: content/CASIA-Aligned-Mask/0631021/17_0.png
#   inflating: content/CASIA-Aligned-Mask/0631021/9_0.png
#   inflating: content/CASIA-Aligned-Mask/0631021/21_0.png
#   inflating: content/CASIA-Aligned-Mask/0631021/1_0.png
#   inflating: content/CASIA-Aligned-Mask/0631021/10_0.png
#   inflating: content/CASIA-Aligned-Mask/0631021/4_0.png
#   inflating: content/CASIA-Aligned-Mask/0631021/0_0.png
#   inflating: content/CASIA-Aligned-Mask/0631021/3_0.png
#   inflating: content/CASIA-Aligned-Mask/0631021/19_0.png
#   inflating: content/CASIA-Aligned-Mask/0631021/14_0.png
#    creating: content/CASIA-Aligned-Mask/0225269/
#   inflating: content/CASIA-Aligned-Mask/0225269/12_0.png
#   inflating: content/CASIA-Aligned-Mask/0225269/8_0.png
#   inflating: content/CASIA-Aligned-Mask/0225269/2_0.png
#   inflating: content/CASIA-Aligned-Mask/0225269/9_0.png
#   inflating: content/CASIA-Aligned-Mask/0225269/1_0.png
#   inflating: content/CASIA-Aligned-Mask/0225269/7_0.png
#   inflating: content/CASIA-Aligned-Mask/0225269/10_0.png
#   inflating: content/CASIA-Aligned-Mask/0225269/0_0.png
# ...
#   inflating: content/CASIA-Aligned-Mask/0623604/14_0.png
#   inflating: content/CASIA-Aligned-Mask/0623604/46_0.png
#    creating: content/CASIA-Aligned-Mask/0001759/
#   inflating: content/CASIA-Aligned-Mask/0001759/12_0.png
#   inflating: content/CASIA-Aligned-Mask/0001759/8_0.png
#   inflating: content/CASIA-Aligned-Mask/0001759/2_0.png
#   inflating: content/CASIA-Aligned-Mask/0001759/16_0.png
#   inflating: content/CASIA-Aligned-Mask/0001759/9_0.png
#   inflating: content/CASIA-Aligned-Mask/0001759/1_0.png
#   inflating: content/CASIA-Aligned-Mask/0001759/7_0.png
#   inflating: content/CASIA-Aligned-Mask/0001759/10_0.png
#   inflating: content/CASIA-Aligned-Mask/0001759/5_0.png
#   inflating: content/CASIA-Aligned-Mask/0001759/11_0.png
#   inflating: content/CASIA-Aligned-Mask/0001759/15_0.png
#   inflating: content/CASIA-Aligned-Mask/0001759/14_0.png
#    creating: content/CASIA-Aligned-Mask/0024404/
#   inflating: content/CASIA-Aligned-Mask/0024404/42_0.png
#   inflating: content/CASIA-Aligned-Mask/0024404/39_0.png
#   inflating: content/CASIA-Aligned-Mask/0024404/47_0.png
#   inflating: content/CASIA-Aligned-Mask/0024404/22_0.png
#   inflating: content/CASIA-Aligned-Mask/0024404/25_0.png
#   inflating: content/CASIA-Aligned-Mask/0024404/12_0.png
#   inflating: content/CASIA-Aligned-Mask/0024404/8_0.png
#   inflating: content/CASIA-Aligned-Mask/0024404/56_0.png
#   inflating: content/CASIA-Aligned-Mask/0024404/2_0.png
#   inflating: content/CASIA-Aligned-Mask/0024404/26_0.png
#   inflating: content/CASIA-Aligned-Mask/0024404/17_0.png
#   inflating: content/CASIA-Aligned-Mask/0024404/54_0.png
#   inflating: content/CASIA-Aligned-Mask/0024404/30_0.png
#   inflating: content/CASIA-Aligned-Mask/0024404/51_0.png
#   inflating: content/CASIA-Aligned-Mask/0024404/49_0.png
#   inflating: content/CASIA-Aligned-Mask/0024404/53_0.png
#   inflating: content/CASIA-Aligned-Mask/0024404/21_0.png
#   inflating: content/CASIA-Aligned-Mask/0024404/60_0.png
#   inflating: content/CASIA-Aligned-Mask/0024404/6_0.png
#   inflating: content/CASIA-Aligned-Mask/0024404/45_0.png
#   inflating: content/CASIA-Aligned-Mask/0024404/29_0.png
#   inflating: content/CASIA-Aligned-Mask/0024404/43_0.png
#   inflating: content/CASIA-Aligned-Mask/0024404/1_0.png
#   inflating: content/CASIA-Aligned-Mask/0024404/10_0.png
#   inflating: content/CASIA-Aligned-Mask/0024404/18_0.png
#   inflating: content/CASIA-Aligned-Mask/0024404/23_0.png
#   inflating: content/CASIA-Aligned-Mask/0024404/27_0.png
#   inflating: content/CASIA-Aligned-Mask/0024404/55_0.png
#   inflating: content/CASIA-Aligned-Mask/0024404/41_0.png
#   inflating: content/CASIA-Aligned-Mask/0024404/64_0.png
#   inflating: content/CASIA-Aligned-Mask/0024404/36_0.png
#   inflating: content/CASIA-Aligned-Mask/0024404/4_0.png
#   inflating: content/CASIA-Aligned-Mask/0024404/0_0.png
#   inflating: content/CASIA-Aligned-Mask/0024404/63_0.png
#   inflating: content/CASIA-Aligned-Mask/0024404/50_0.png
#   inflating: content/CASIA-Aligned-Mask/0024404/62_0.png
#   inflating: content/CASIA-Aligned-Mask/0024404/48_0.png
#   inflating: content/CASIA-Aligned-Mask/0024404/5_0.png
#   inflating: content/CASIA-Aligned-Mask/0024404/3_0.png
#   inflating: content/CASIA-Aligned-Mask/0024404/11_0.png
#   inflating: content/CASIA-Aligned-Mask/0024404/19_0.png
#   inflating: content/CASIA-Aligned-Mask/0024404/28_0.png
#   inflating: content/CASIA-Aligned-Mask/0024404/57_0.png
#   inflating: content/CASIA-Aligned-Mask/0024404/34_0.png
#   inflating: content/CASIA-Aligned-Mask/0024404/15_0.png
#   inflating: content/CASIA-Aligned-Mask/0024404/35_0.png
#   inflating: content/CASIA-Aligned-Mask/0024404/37_0.png
#   inflating: content/CASIA-Aligned-Mask/0024404/20_0.png
#   inflating: content/CASIA-Aligned-Mask/0024404/46_0.png
#    creating: content/CASIA-Aligned-Mask/0005429/
#   inflating: content/CASIA-Aligned-Mask/0005429/47_0.png
#   inflating: content/CASIA-Aligned-Mask/0005429/22_0.png
#   inflating: content/CASIA-Aligned-Mask/0005429/25_0.png
#   inflating: content/CASIA-Aligned-Mask/0005429/12_0.png
#   inflating: content/CASIA-Aligned-Mask/0005429/33_0.png
#   inflating: content/CASIA-Aligned-Mask/0005429/2_0.png
#   inflating: content/CASIA-Aligned-Mask/0005429/26_0.png
#   inflating: content/CASIA-Aligned-Mask/0005429/17_0.png
#   inflating: content/CASIA-Aligned-Mask/0005429/30_0.png
#   inflating: content/CASIA-Aligned-Mask/0005429/16_0.png
#   inflating: content/CASIA-Aligned-Mask/0005429/49_0.png
#   inflating: content/CASIA-Aligned-Mask/0005429/21_0.png
#   inflating: content/CASIA-Aligned-Mask/0005429/52_0.png
#   inflating: content/CASIA-Aligned-Mask/0005429/6_0.png
#   inflating: content/CASIA-Aligned-Mask/0005429/45_0.png
#   inflating: content/CASIA-Aligned-Mask/0005429/29_0.png
#   inflating: content/CASIA-Aligned-Mask/0005429/1_0.png
#   inflating: content/CASIA-Aligned-Mask/0005429/7_0.png
#   inflating: content/CASIA-Aligned-Mask/0005429/32_0.png
#   inflating: content/CASIA-Aligned-Mask/0005429/18_0.png
#   inflating: content/CASIA-Aligned-Mask/0005429/23_0.png
#   inflating: content/CASIA-Aligned-Mask/0005429/41_0.png
#   inflating: content/CASIA-Aligned-Mask/0005429/36_0.png
#   inflating: content/CASIA-Aligned-Mask/0005429/13_0.png
#   inflating: content/CASIA-Aligned-Mask/0005429/50_0.png
#   inflating: content/CASIA-Aligned-Mask/0005429/48_0.png
#   inflating: content/CASIA-Aligned-Mask/0005429/5_0.png
#   inflating: content/CASIA-Aligned-Mask/0005429/3_0.png
#   inflating: content/CASIA-Aligned-Mask/0005429/11_0.png
#   inflating: content/CASIA-Aligned-Mask/0005429/19_0.png
#   inflating: content/CASIA-Aligned-Mask/0005429/14_0.png
#   inflating: content/CASIA-Aligned-Mask/0005429/46_0.png
#    creating: content/CASIA-Aligned-Mask/0493161/
#   inflating: content/CASIA-Aligned-Mask/0493161/39_0.png
#   inflating: content/CASIA-Aligned-Mask/0493161/25_0.png
#   inflating: content/CASIA-Aligned-Mask/0493161/30_0.png
#   inflating: content/CASIA-Aligned-Mask/0493161/16_0.png
#   inflating: content/CASIA-Aligned-Mask/0493161/9_0.png
#   inflating: content/CASIA-Aligned-Mask/0493161/21_0.png
#   inflating: content/CASIA-Aligned-Mask/0493161/29_0.png
#   inflating: content/CASIA-Aligned-Mask/0493161/1_0.png
#   inflating: content/CASIA-Aligned-Mask/0493161/32_0.png
#   inflating: content/CASIA-Aligned-Mask/0493161/23_0.png
#   inflating: content/CASIA-Aligned-Mask/0493161/24_0.png
#   inflating: content/CASIA-Aligned-Mask/0493161/36_0.png
#   inflating: content/CASIA-Aligned-Mask/0493161/5_0.png
#   inflating: content/CASIA-Aligned-Mask/0493161/28_0.png
#   inflating: content/CASIA-Aligned-Mask/0493161/34_0.png
#   inflating: content/CASIA-Aligned-Mask/0493161/15_0.png
#   inflating: content/CASIA-Aligned-Mask/0493161/20_0.png
#    creating: content/CASIA-Aligned-Mask/0005347/
#   inflating: content/CASIA-Aligned-Mask/0005347/8_0.png
#   inflating: content/CASIA-Aligned-Mask/0005347/2_0.png
#   inflating: content/CASIA-Aligned-Mask/0005347/9_0.png
#   inflating: content/CASIA-Aligned-Mask/0005347/6_0.png
#   inflating: content/CASIA-Aligned-Mask/0005347/1_0.png
#   inflating: content/CASIA-Aligned-Mask/0005347/7_0.png
#   inflating: content/CASIA-Aligned-Mask/0005347/10_0.png
#   inflating: content/CASIA-Aligned-Mask/0005347/0_0.png
#   inflating: content/CASIA-Aligned-Mask/0005347/5_0.png
#   inflating: content/CASIA-Aligned-Mask/0005347/3_0.png
#   inflating: content/CASIA-Aligned-Mask/0005347/11_0.png
#    creating: content/CASIA-Aligned-Mask/0237910/
#   inflating: content/CASIA-Aligned-Mask/0237910/8_0.png
#   inflating: content/CASIA-Aligned-Mask/0237910/2_0.png
#   inflating: content/CASIA-Aligned-Mask/0237910/17_0.png
#   inflating: content/CASIA-Aligned-Mask/0237910/16_0.png
#   inflating: content/CASIA-Aligned-Mask/0237910/1_0.png
#   inflating: content/CASIA-Aligned-Mask/0237910/7_0.png
#   inflating: content/CASIA-Aligned-Mask/0237910/10_0.png
#   inflating: content/CASIA-Aligned-Mask/0237910/18_0.png
#   inflating: content/CASIA-Aligned-Mask/0237910/23_0.png
#   inflating: content/CASIA-Aligned-Mask/0237910/24_0.png
#   inflating: content/CASIA-Aligned-Mask/0237910/0_0.png
#   inflating: content/CASIA-Aligned-Mask/0237910/13_0.png
#   inflating: content/CASIA-Aligned-Mask/0237910/5_0.png
#   inflating: content/CASIA-Aligned-Mask/0237910/3_0.png
#   inflating: content/CASIA-Aligned-Mask/0237910/19_0.png
#   inflating: content/CASIA-Aligned-Mask/0237910/15_0.png
#   inflating: content/CASIA-Aligned-Mask/0237910/20_0.png
#   inflating: content/CASIA-Aligned-Mask/0237910/14_0.png
#    creating: content/CASIA-Aligned-Mask/0504762/
#   inflating: content/CASIA-Aligned-Mask/0504762/12_0.png
#   inflating: content/CASIA-Aligned-Mask/0504762/8_0.png
#   inflating: content/CASIA-Aligned-Mask/0504762/2_0.png
#   inflating: content/CASIA-Aligned-Mask/0504762/17_0.png
#   inflating: content/CASIA-Aligned-Mask/0504762/16_0.png
#   inflating: content/CASIA-Aligned-Mask/0504762/6_0.png
#   inflating: content/CASIA-Aligned-Mask/0504762/1_0.png
#   inflating: content/CASIA-Aligned-Mask/0504762/7_0.png
#   inflating: content/CASIA-Aligned-Mask/0504762/10_0.png
#   inflating: content/CASIA-Aligned-Mask/0504762/4_0.png
#   inflating: content/CASIA-Aligned-Mask/0504762/0_0.png
#   inflating: content/CASIA-Aligned-Mask/0504762/5_0.png
#   inflating: content/CASIA-Aligned-Mask/0504762/11_0.png
#   inflating: content/CASIA-Aligned-Mask/0504762/19_0.png
#   inflating: content/CASIA-Aligned-Mask/0504762/15_0.png
#   inflating: content/CASIA-Aligned-Mask/0504762/20_0.png
#   inflating: content/CASIA-Aligned-Mask/0504762/14_0.png
#    creating: content/CASIA-Aligned-Mask/0524240/
#   inflating: content/CASIA-Aligned-Mask/0524240/22_0.png
#   inflating: content/CASIA-Aligned-Mask/0524240/12_0.png
#   inflating: content/CASIA-Aligned-Mask/0524240/17_0.png
#   inflating: content/CASIA-Aligned-Mask/0524240/16_0.png
#   inflating: content/CASIA-Aligned-Mask/0524240/9_0.png
#   inflating: content/CASIA-Aligned-Mask/0524240/21_0.png
#   inflating: content/CASIA-Aligned-Mask/0524240/6_0.png
#   inflating: content/CASIA-Aligned-Mask/0524240/1_0.png
#   inflating: content/CASIA-Aligned-Mask/0524240/18_0.png
#   inflating: content/CASIA-Aligned-Mask/0524240/24_0.png
#   inflating: content/CASIA-Aligned-Mask/0524240/13_0.png
#   inflating: content/CASIA-Aligned-Mask/0524240/5_0.png
#   inflating: content/CASIA-Aligned-Mask/0524240/11_0.png
#   inflating: content/CASIA-Aligned-Mask/0524240/15_0.png
#   inflating: content/CASIA-Aligned-Mask/0524240/20_0.png
#    creating: content/CASIA-Aligned-Mask/0601003/
#   inflating: content/CASIA-Aligned-Mask/0601003/2_0.png
#   inflating: content/CASIA-Aligned-Mask/0601003/9_0.png
#   inflating: content/CASIA-Aligned-Mask/0601003/7_0.png
#   inflating: content/CASIA-Aligned-Mask/0601003/10_0.png
#   inflating: content/CASIA-Aligned-Mask/0601003/0_0.png
#   inflating: content/CASIA-Aligned-Mask/0601003/13_0.png
#    creating: content/CASIA-Aligned-Mask/0188027/
#   inflating: content/CASIA-Aligned-Mask/0188027/12_0.png
#   inflating: content/CASIA-Aligned-Mask/0188027/8_0.png
#   inflating: content/CASIA-Aligned-Mask/0188027/2_0.png
#   inflating: content/CASIA-Aligned-Mask/0188027/9_0.png
#   inflating: content/CASIA-Aligned-Mask/0188027/6_0.png
#   inflating: content/CASIA-Aligned-Mask/0188027/1_0.png
#   inflating: content/CASIA-Aligned-Mask/0188027/7_0.png
#   inflating: content/CASIA-Aligned-Mask/0188027/10_0.png
#   inflating: content/CASIA-Aligned-Mask/0188027/4_0.png
#   inflating: content/CASIA-Aligned-Mask/0188027/0_0.png
#   inflating: content/CASIA-Aligned-Mask/0188027/13_0.png
#   inflating: content/CASIA-Aligned-Mask/0188027/5_0.png
#   inflating: content/CASIA-Aligned-Mask/0188027/11_0.png
#   inflating: content/CASIA-Aligned-Mask/0188027/14_0.png
#    creating: content/CASIA-Aligned-Mask/0112085/
#   inflating: content/CASIA-Aligned-Mask/0112085/22_0.png
#   inflating: content/CASIA-Aligned-Mask/0112085/25_0.png
#   inflating: content/CASIA-Aligned-Mask/0112085/8_0.png
#   inflating: content/CASIA-Aligned-Mask/0112085/2_0.png
#   inflating: content/CASIA-Aligned-Mask/0112085/26_0.png
#   inflating: content/CASIA-Aligned-Mask/0112085/17_0.png
#   inflating: content/CASIA-Aligned-Mask/0112085/16_0.png
#   inflating: content/CASIA-Aligned-Mask/0112085/9_0.png
#   inflating: content/CASIA-Aligned-Mask/0112085/21_0.png
#   inflating: content/CASIA-Aligned-Mask/0112085/31_0.png
#   inflating: content/CASIA-Aligned-Mask/0112085/1_0.png
#   inflating: content/CASIA-Aligned-Mask/0112085/7_0.png
#   inflating: content/CASIA-Aligned-Mask/0112085/10_0.png
#   inflating: content/CASIA-Aligned-Mask/0112085/18_0.png
#   inflating: content/CASIA-Aligned-Mask/0112085/23_0.png
#   inflating: content/CASIA-Aligned-Mask/0112085/24_0.png
#   inflating: content/CASIA-Aligned-Mask/0112085/4_0.png
#   inflating: content/CASIA-Aligned-Mask/0112085/5_0.png
#   inflating: content/CASIA-Aligned-Mask/0112085/19_0.png
#   inflating: content/CASIA-Aligned-Mask/0112085/28_0.png
#   inflating: content/CASIA-Aligned-Mask/0112085/15_0.png
#   inflating: content/CASIA-Aligned-Mask/0112085/20_0.png
#   inflating: content/CASIA-Aligned-Mask/0112085/14_0.png
#    creating: content/CASIA-Aligned-Mask/0496934/
#   inflating: content/CASIA-Aligned-Mask/0496934/39_0.png
#   inflating: content/CASIA-Aligned-Mask/0496934/47_0.png
#   inflating: content/CASIA-Aligned-Mask/0496934/22_0.png
#   inflating: content/CASIA-Aligned-Mask/0496934/12_0.png
#   inflating: content/CASIA-Aligned-Mask/0496934/33_0.png
#   inflating: content/CASIA-Aligned-Mask/0496934/8_0.png
#   inflating: content/CASIA-Aligned-Mask/0496934/2_0.png
#   inflating: content/CASIA-Aligned-Mask/0496934/26_0.png
#   inflating: content/CASIA-Aligned-Mask/0496934/54_0.png
#   inflating: content/CASIA-Aligned-Mask/0496934/30_0.png
#   inflating: content/CASIA-Aligned-Mask/0496934/38_0.png
#   inflating: content/CASIA-Aligned-Mask/0496934/51_0.png
#   inflating: content/CASIA-Aligned-Mask/0496934/40_0.png
#   inflating: content/CASIA-Aligned-Mask/0496934/49_0.png
#   inflating: content/CASIA-Aligned-Mask/0496934/53_0.png
#   inflating: content/CASIA-Aligned-Mask/0496934/21_0.png
#   inflating: content/CASIA-Aligned-Mask/0496934/52_0.png
#   inflating: content/CASIA-Aligned-Mask/0496934/6_0.png
#   inflating: content/CASIA-Aligned-Mask/0496934/31_0.png
#   inflating: content/CASIA-Aligned-Mask/0496934/45_0.png
#   inflating: content/CASIA-Aligned-Mask/0496934/29_0.png
#   inflating: content/CASIA-Aligned-Mask/0496934/43_0.png
#   inflating: content/CASIA-Aligned-Mask/0496934/1_0.png
#   inflating: content/CASIA-Aligned-Mask/0496934/7_0.png
#   inflating: content/CASIA-Aligned-Mask/0496934/10_0.png
#   inflating: content/CASIA-Aligned-Mask/0496934/18_0.png
#   inflating: content/CASIA-Aligned-Mask/0496934/23_0.png
#   inflating: content/CASIA-Aligned-Mask/0496934/27_0.png
#   inflating: content/CASIA-Aligned-Mask/0496934/55_0.png
#   inflating: content/CASIA-Aligned-Mask/0496934/41_0.png
#   inflating: content/CASIA-Aligned-Mask/0496934/36_0.png
#   inflating: content/CASIA-Aligned-Mask/0496934/4_0.png
#   inflating: content/CASIA-Aligned-Mask/0496934/0_0.png
#   inflating: content/CASIA-Aligned-Mask/0496934/13_0.png
#   inflating: content/CASIA-Aligned-Mask/0496934/50_0.png
#   inflating: content/CASIA-Aligned-Mask/0496934/5_0.png
#   inflating: content/CASIA-Aligned-Mask/0496934/3_0.png
#   inflating: content/CASIA-Aligned-Mask/0496934/11_0.png
#   inflating: content/CASIA-Aligned-Mask/0496934/19_0.png
#   inflating: content/CASIA-Aligned-Mask/0496934/28_0.png
#   inflating: content/CASIA-Aligned-Mask/0496934/57_0.png
#   inflating: content/CASIA-Aligned-Mask/0496934/34_0.png
#   inflating: content/CASIA-Aligned-Mask/0496934/15_0.png
#   inflating: content/CASIA-Aligned-Mask/0496934/37_0.png
#   inflating: content/CASIA-Aligned-Mask/0496934/20_0.png
#   inflating: content/CASIA-Aligned-Mask/0496934/46_0.png

# %%
# !unrar x '/content/drive/MyDrive/lfw-aligned/LFW_aligned.rar' '/content/content/'

# %%
import os,cv2,json,time
import numpy as np
import tensorflow
import math

from inception_resnet_v1 import inference as inception_resnet_v1
from inception_resnet_v1_reduction import inference_reduction as inception_resnet_v1_reduction
from validate_on_lfw import get_paths, read_pairs, evaluate
from sklearn import metrics


#----tensorflow version check
if tensorflow.__version__.startswith('1.'):
    import tensorflow as tf
    from tensorflow.python.platform import gfile
else:
    import tensorflow.compat.v1 as tf
    tf.disable_v2_behavior()
    import tensorflow.compat.v1.gfile as gfile

print("Tensorflow version: ",tf.__version__)


class Facenet():
    def __init__(self,para_dict):
        #----var parsing
        train_img_dir = para_dict['train_img_dir']#CASIA
        test_img_dir = para_dict['test_img_dir']#LFW
        label_dict = para_dict['label_dict']

        #----get label names to number dictionary
        # if label_dict is None:
        #     label_dict = self.__get_label_dict(train_img_dir)
        #     print(label_dict)
        #
        # class_num = len(label_dict.keys())

        # ----read training set paths and labels
        if isinstance(train_img_dir, list):
            for idx, img_dir in enumerate(train_img_dir):
                if idx == 0:
                    # ----get label names to number dictionary
                    label_dict = self.__get_label_dict(img_dir)
                    train_paths, train_labels = self.__get_paths_labels(img_dir, label_dict)
                elif idx > 0:
                    temp_paths, temp_labels = self.__get_paths_labels(img_dir, label_dict)
                    train_paths = np.concatenate([train_paths, temp_paths], axis=0)
                    train_labels = np.concatenate([train_labels, temp_labels], axis=0)
        else:
            # ----get label names to number dictionary
            label_dict = self.__get_label_dict(train_img_dir)
            train_paths, train_labels = self.__get_paths_labels(train_img_dir, label_dict)
        class_num = len(label_dict.keys())
        print("train path shape:{}, train label shape:{}".format(train_paths.shape, train_labels.shape))
        print("class number:", class_num)

        #----read test set paths and labels
        # if test_img_dir is not None:
        #     test_paths, test_labels = self.__get_paths_labels(test_img_dir,label_dict)
        #     print("test path shape:{}, test label shape:{}".format(test_paths.shape, test_labels.shape))

        #----log update
        content = dict()
        content = self.log_update(content,para_dict)

        #----local var to global
        self.train_img_dir = train_img_dir
        self.test_img_dir = test_img_dir
        self.label_dict = label_dict
        self.train_paths = train_paths
        self.train_labels = train_labels
        self.class_num = class_num
        self.content = content
        # if test_img_dir is not None:
        #     self.test_img_dir = test_img_dir
        #     self.test_paths = test_paths
        #     self.test_labels = test_labels

    def model_init(self,para_dict):
        #----var parsing
        model_shape = para_dict['model_shape']#[N,H,W,C]
        infer_method = para_dict['infer_method']
        loss_method = para_dict['loss_method']
        opti_method = para_dict['opti_method']
        learning_rate = para_dict['learning_rate']
        save_dir = para_dict['save_dir']
        embed_length = para_dict['embed_length']

        #----tf_placeholder declaration
        tf_input = tf.placeholder(dtype=tf.float32,shape=model_shape,name='input')
        tf_keep_prob = tf.placeholder(dtype=tf.float32,name="keep_prob")
        tf_label_batch = tf.placeholder(dtype=tf.int32,shape=[None],name="label_batch")
        tf_phase_train = tf.placeholder(dtype=tf.bool,name="phase_train")

        #---inference selection
        if infer_method == "inception_resnet_v1":
            prelogits, _ = inception_resnet_v1(tf_input, tf_keep_prob, phase_train=tf_phase_train,
              bottleneck_layer_size=embed_length, weight_decay=0.0, reuse=None)
            embeddings = tf.nn.l2_normalize(prelogits, 1, 1e-10, name='embeddings')
        elif infer_method == "inception_resnet_v1_reduction":
            prelogits, _ = inception_resnet_v1_reduction(tf_input, tf_keep_prob,phase_train=tf_phase_train,
                                                         bottleneck_layer_size=embed_length, weight_decay=0.0,
                                                         reuse=None)
            # prelogits = tf.identity(prelogits, name='prelogits')
            embeddings = tf.nn.l2_normalize(prelogits, 1, 1e-10, name='embeddings')


        #---loss selection
        if loss_method == "cross_entropy":
            output = tf.layers.dense(inputs=prelogits, units=self.class_num, activation=None, name="output")
            prediction = tf.nn.softmax(output,name="prediction")
            loss = tf.reduce_mean(tf.nn.sparse_softmax_cross_entropy_with_logits(labels=tf_label_batch,logits=output),
                                  name="loss")

        #----optimizer selection
        if opti_method == "adam":
            optimizer = tf.train.AdamOptimizer(learning_rate=learning_rate).minimize(loss)


        #----create the dir to save model weights(CKPT, PB)
        if not os.path.exists(save_dir):
            os.makedirs(save_dir)

        out_dir_prefix = os.path.join(save_dir,"model")
        saver = tf.train.Saver(max_to_keep=5)


        #----appoint PB node names
        pb_save_path = os.path.join(save_dir,"pb_model.pb")
        pb_save_list = ['prediction',"embeddings"]


        #----create the log(JSON)
        count = 0
        for i in range(100):
            log_path = os.path.join(save_dir,"train_result_" + str(count) + ".json")
            if not os.path.exists(log_path):
                break
            count += 1
        print("log_path: ",log_path)
        self.content = self.log_update(self.content,para_dict)

        #----local var to global
        self.tf_input = tf_input
        self.tf_keep_prob = tf_keep_prob
        self.tf_label_batch = tf_label_batch
        self.tf_phase_train = tf_phase_train
        self.embeddings = embeddings
        self.optimizer = optimizer
        self.prediction = prediction
        self.out_dir_prefix = out_dir_prefix
        self.saver = saver
        self.pb_save_path = pb_save_path
        self.pb_save_list = pb_save_list
        self.log_path = log_path
        self.save_dir = save_dir
        self.model_shape = model_shape
        self.loss = loss

    def train(self,para_dict):
        #----var parsing
        epochs = para_dict['epochs']
        GPU_ratio = para_dict['GPU_ratio']
        batch_size = para_dict['batch_size']
        ratio=para_dict['ratio']
        process_dict = para_dict['process_dict']

        #----local var
        train_loss_list = list()
        train_acc_list = list()
        test_loss_list = list()
        test_acc_list = list()
        epoch_time_list = list()
        img_quantity = 0
        aug_enable = False

        self.content = self.log_update(self.content, para_dict)

        #----ratio
        if ratio <= 1.0:
            img_quantity = int(self.train_paths.shape[0] * ratio)
        else:
            img_quantity = self.train_paths.shape[0]

        #----check if the augmentation(image processing) is enabled
        if isinstance(process_dict,dict):
            if True in process_dict.values():
                aug_enable = True
                batch_size = batch_size // 2  #the batch size must be integer!!


        #----calculate iterations of one epoch
        train_ites = math.ceil(img_quantity / batch_size)
        # if self.test_img_dir is not None:
        #     test_ites = math.ceil(self.test_paths.shape[0] / batch_size)

        #----GPU setting
        config = tf.ConfigProto(log_device_placement=True,
                                allow_soft_placement=True)
        if GPU_ratio is None:
            config.gpu_options.allow_growth = True
        else:
            config.gpu_options.per_process_gpu_memory_fraction = GPU_ratio

        with tf.Session(config=config) as sess:
            #----tranfer learning check
            files = [file.path for file in os.scandir(self.save_dir) if file.name.split(".")[-1] == 'meta']
            if len(files) == 0:
                sess.run(tf.global_variables_initializer())
                print("no previous model param can be used!")
            else:
                check_name = files[-1].split("/")[-1].split(".")[0]
                model_path = os.path.join(self.save_dir,check_name)
                self.saver.restore(sess,model_path)
                msg = "use previous model param:{}".format(model_path)
                print(msg)

            #----info display
            print("img_quantity:", img_quantity)
            if aug_enable is True:
                print("aug_enable is True, the data quantity of one epoch is doubled")

            #----epoch training
            for epoch in range(epochs):
                #----record the start time
                d_t = time.time()

                train_loss = 0
                train_acc = 0
                test_loss = 0
                test_acc = 0

                #----shuffle
                indice = np.random.permutation(self.train_paths.shape[0])
                self.train_paths = self.train_paths[indice]
                self.train_labels = self.train_labels[indice]
                train_paths_ori = self.train_paths[:img_quantity]
                train_labels_ori = self.train_labels[:img_quantity]

                if aug_enable is True:
                    train_paths_aug = train_paths_ori[::-1]
                    train_labels_aug = train_labels_ori[::-1]

                #----do optimizers(training by iteration)
                for index in range(train_ites):
                    #----get image start and end numbers
                    num_start = index * batch_size
                    num_end = np.minimum(num_start + batch_size, self.train_paths.shape[0])

                    # ----get 4-D data
                    if aug_enable is True:
                        #----ori data
                        ori_data = self.get_4D_data(train_paths_ori[num_start:num_end], self.model_shape[1:],
                                                    process_dict=None)
                        ori_labels = train_labels_ori[num_start:num_end]
                        #----aug data
                        aug_data = self.get_4D_data(train_paths_aug[num_start:num_end], self.model_shape[1:],
                                                    process_dict=process_dict)
                        aug_labels = train_labels_aug[num_start:num_end]
                        # ----data concat
                        batch_data = np.concatenate([ori_data, aug_data], axis=0)
                        batch_labels = np.concatenate([ori_labels, aug_labels], axis=0)

                    else:
                        batch_data = self.get_4D_data(train_paths_ori[num_start:num_end], self.model_shape[1:])
                        batch_labels = train_labels_ori[num_start:num_end]

                    #----put all data to tf placeholders
                    feed_dict = {self.tf_input:batch_data,
                                 self.tf_label_batch:batch_labels,
                                 self.tf_keep_prob:0.8,
                                 self.tf_phase_train:True}

                    #----session run
                    sess.run(self.optimizer,feed_dict=feed_dict)

                    #----evaluation(training set)
                    feed_dict[self.tf_keep_prob] = 1.0
                    feed_dict[self.tf_phase_train] = False
                    loss_temp, predict_temp = sess.run([self.loss, self.prediction], feed_dict=feed_dict)

                    # ----calculate the loss and accuracy
                    train_loss += loss_temp
                    train_acc += self.evaluation(predict_temp, batch_labels)

                train_loss /= train_ites
                train_acc /= self.train_paths.shape[0]
                if aug_enable is True:#divided by 2 because the training data quantity is doubled
                    train_acc /= 2

                #-----testing set(LFW) evaluation
                if self.test_img_dir is not None:
                    test_acc = self.eval_on_lfw(sess, feed_dict, self.test_img_dir, batch_size=batch_size)

                #----save ckpt, pb files
                model_save_path = self.saver.save(sess,self.out_dir_prefix,global_step=epoch)
                print("save model CKPT to ",model_save_path)

                graph = tf.get_default_graph().as_graph_def()
                output_graph_def = tf.graph_util.convert_variables_to_constants(sess,graph,self.pb_save_list)
                with tf.gfile.GFile(self.pb_save_path,'wb')as f:
                    f.write(output_graph_def.SerializeToString())
                print("save PB file to ",self.pb_save_path)

                #----record the end time
                d_t = time.time() - d_t

                #----save results in the log file
                train_loss_list.append(float(train_loss))
                train_acc_list.append(float(train_acc))
                if self.test_img_dir is not None:
                    #test_loss_list.append(float(test_loss))
                    test_acc_list.append(float(test_acc))

                self.content["train_loss_list"] = train_loss_list
                self.content["train_acc_list"] = train_acc_list
                if self.test_img_dir is not None:
                    #self.content["test_loss_list"] = test_loss_list
                    self.content["test_acc_list"] = test_acc_list

                epoch_time_list.append(d_t)
                self.content['ave_epoch_time'] = float(np.average(epoch_time_list))

                with open(self.log_path, 'w') as f:
                    json.dump(self.content,f)

                print("save the log file in ",self.log_path)



                #----display training results
                print("Epoch: ",epoch)
                print("training loss:{}, accuracy:{}".format(train_loss,train_acc))
                if self.test_img_dir is not None:
                    print("test set accuracy:{}".format( test_acc))

                print("Epoch time consumption:",d_t)

    #----functions
    def log_update(self,content,para_dict):
        for key, value in para_dict.items():
            content[key] = value

        return content

    def evaluation(self,predictions,labels):
        count = 0
        for i in range(predictions.shape[0]):
            if np.argmax(predictions[i]) == labels[i]:
                count += 1

        return count

    def get_4D_data(self, paths, img_shape, process_dict=None):
        # ----var
        re_array = []
        processing_enable = False

        # ----check process_dict
        if isinstance(process_dict, dict):
            if len(process_dict) > 0:
                processing_enable = True  # image processing is enabled
                height, width = img_shape[:2]
                height_rdm_crop = int(height * 1.15)
                width_rdm_crop = int(width * 1.15)
                y_range = height_rdm_crop - height
                x_range = width_rdm_crop - width
                flip_list = [1, 0]

        for path in paths:
            img = cv2.imread(path)
            if img is None:
                print("read failed:", path)
            else:
                # ----image processing
                if processing_enable is True:
                    if 'rdm_crop' in process_dict.keys():
                        if process_dict['rdm_crop'] is True:
                            img = cv2.resize(img, (width_rdm_crop, height_rdm_crop))

                            # ----Find a random point
                            x_start = np.random.randint(x_range)
                            y_start = np.random.randint(y_range)

                            # ----From the random point, crop the image
                            img = img[y_start:y_start + height, x_start:x_start + width, :]
                    if 'rdm_br' in process_dict.keys():
                        if process_dict['rdm_br'] is True:
                            mean_br = np.mean(img)
                            br_factor = np.random.randint(mean_br * 0.7, mean_br * 1.3)
                            img = np.clip(img / mean_br * br_factor, 0, 255)#the multification makes the numeric type become floating
                            img = img.astype(np.uint8) #transform the numeric type to unsigned integer 8(UINT8)
                    if 'rdm_flip' in process_dict.keys():
                        if process_dict['rdm_flip'] is True:
                            flip_type = np.random.choice(flip_list)
                            if flip_type == 1:
                                img = cv2.flip(img, flip_type)
                    if 'rdm_noise' in process_dict.keys():
                        if process_dict['rdm_noise'] is True:
                            uniform_noise = np.empty((img.shape[0], img.shape[1]), dtype=np.uint8)
                            cv2.randu(uniform_noise, 0, 255)
                            ret, impulse_noise = cv2.threshold(uniform_noise, 230, 255, cv2.THRESH_BINARY_INV)
                            img = cv2.bitwise_and(img, img, mask=impulse_noise)
                    if 'rdm_angle' in process_dict.keys():
                        if process_dict['rdm_angle'] is True:
                            angle = np.random.randint(-60, 60)
                            h, w = img.shape[:2]
                            M = cv2.getRotationMatrix2D((w // 2, h // 2), angle, 1.0)
                            img = cv2.warpAffine(img, M, (h, w))
                # ----
                img = cv2.resize(img, (img_shape[1], img_shape[0]))
                img = cv2.cvtColor(img, cv2.COLOR_BGR2RGB)
                img = img.astype(np.float32)
                img /= 255
                re_array.append(img)

        re_array = np.array(re_array)

        return re_array

    def get_4D_data_2(self,paths, img_shape, process_dict=None):
        # ----var
        random_flip = False
        random_brightness = False
        random_crop = False
        random_angle = False
        random_noise = False
        flip_list = [1, 0]

        # ----create default np array
        batch_dim = [len(paths)]
        batch_dim.extend(img_shape)
        batch_data = np.zeros(batch_dim, dtype=np.float32)

        # ----update var
        if isinstance(process_dict, dict):
            if 'random_flip' in process_dict.keys():
                random_flip = process_dict['random_flip']
            if 'random_brightness' in process_dict.keys():
                random_brightness = process_dict['random_brightness']
            if 'random_crop' in process_dict.keys():
                random_crop = process_dict['random_crop']
            if 'random_angle' in process_dict.keys():
                random_angle = process_dict['random_angle']
            if 'random_noise' in process_dict.keys():
                random_noise = process_dict['random_noise']

        for idx, path in enumerate(paths):
            img = cv2.imread(path)
            if img is None:
                print("read failed:", path)
            else:
                img = cv2.resize(img, (img_shape[1], img_shape[0]))
                img = cv2.cvtColor(img, cv2.COLOR_BGR2RGB)

                # ----random brightness
                if random_brightness is True:
                    mean_br = np.mean(img)
                    br_factor = np.random.randint(mean_br * 0.7, mean_br * 1.3)
                    img = np.clip(img / mean_br * br_factor, 0, 255)
                    img = img.astype(np.uint8)

                # ----random crop
                if random_crop is True:
                    # ----resize the image 1.15 times
                    img = cv2.resize(img, None, fx=1.15, fy=1.15)

                    # ----Find a random point
                    y_range = img.shape[0] - img_shape[0]
                    x_range = img.shape[1] - img_shape[1]
                    x_start = np.random.randint(x_range)
                    y_start = np.random.randint(y_range)

                    # ----From the random point, crop the image
                    img = img[y_start:y_start + img_shape[0], x_start:x_start + img_shape[1], :]

                # ----random flip
                if random_flip is True:
                    flip_type = np.random.choice(flip_list)
                    if flip_type == 1:
                        img = cv2.flip(img, flip_type)

                # ----random angle
                if random_angle is True:
                    angle = np.random.randint(-60, 60)
                    height, width = img.shape[:2]
                    M = cv2.getRotationMatrix2D((width // 2, height // 2), angle, 1.0)
                    img = cv2.warpAffine(img, M, (width, height))

                # ----random noise
                if random_noise is True:
                    uniform_noise = np.empty((img.shape[0], img.shape[1]), dtype=np.uint8)
                    cv2.randu(uniform_noise, 0, 255)
                    ret, impulse_noise = cv2.threshold(uniform_noise, 240, 255, cv2.THRESH_BINARY_INV)
                    img = cv2.bitwise_and(img, img, mask=impulse_noise)

                batch_data[idx] = img

        batch_data /= 255
        return batch_data

    def eval_on_lfw(self, sess, feed_dict, lfw_dir, batch_size=12):
        # ----Read the file containing the pairs used for testing
        time_eval = time.time()
        lfw_pairs_path = '/content/pairs.txt'
        pairs = read_pairs(os.path.expanduser(lfw_pairs_path))

        # ----Get the paths for the corresponding images
        paths, actual_issame = get_paths(os.path.expanduser(lfw_dir), pairs)

        # ----collect all embeddings
        iterations = math.ceil(len(paths) / batch_size)

        for i in range(iterations):
            n_start = i * batch_size
            n_end = np.minimum(i * batch_size + batch_size, len(paths))

            batch_data = self.get_4D_data(paths[n_start:n_end], self.model_shape[1:])

            feed_dict[self.tf_input] = batch_data
            sess_out = sess.run(self.embeddings, feed_dict=feed_dict)
            if i == 0:
                embeddings = sess_out
            else:
                embeddings = np.concatenate([embeddings, sess_out], axis=0)

        tpr, fpr, accuracy, val, val_std, far = evaluate(embeddings, actual_issame, nrof_folds=10,
                                                         distance_metric=0,
                                                         subtract_mean=False)

        print('Accuracy: %2.5f+-%2.5f' % (np.mean(accuracy), np.std(accuracy)))
        print('Validation rate: %2.5f+-%2.5f @ FAR=%2.5f' % (val, val_std, far))

        auc = metrics.auc(fpr, tpr)
        print('Area Under Curve (AUC): %1.3f' % auc)

        time_eval = time.time() - time_eval
        print("Eval on LFW time:", time_eval)

        return np.mean(accuracy)

    def __get_label_dict(self,img_dir):
        label_dict = dict()
        count = 0
        for obj in os.scandir(img_dir):
            if obj.is_dir():
                label_dict[obj.name] = count
                count += 1
        if count == 0:
            print("No dir in the ",img_dir)
            return None
        else:
            return label_dict

    def __get_paths_labels(self,img_dir,label_dict):
        #----var
        img_format = {'png', 'jpg', 'bmp'}
        re_paths = list()
        re_labels = list()

        #----read dirs
        dirs = [obj.path for obj in os.scandir(img_dir) if obj.is_dir()]
        if len(dirs) == 0:
            print("No dirs in the ",img_dir)
        else:
            #-----read paths of each dir
            for dir_path in dirs:
                path_temp = [file.path for file in os.scandir(dir_path) if file.name.split(".")[-1] in img_format]
                if len(path_temp) == 0:
                    print("No images in the ",dir_path)
                else:
                    #----get the label number from class name
                    label_num = dir_path.split("/")[-1]
                    label_num = label_dict[label_num]
                    #----create the label array
                    label_temp = np.ones(len(path_temp),dtype=np.int32) * label_num

                    #----collect paths and labels
                    re_paths.extend(path_temp)
                    re_labels.extend(label_temp)

            #----list to numpy array
            re_paths = np.array(re_paths)
            re_labels = np.array(re_labels)

            #----shuffle
            indice = np.random.permutation(re_paths.shape[0])
            re_paths = re_paths[indice]
            re_labels = re_labels[indice]

        return re_paths, re_labels


    

if __name__ == "__main__":
    train_img_dir = ["/content/content/CASIA-Aligned",
                     "/content/content/CASIA-Aligned-Mask"]
    test_img_dir = "/content/content/lfw-aligned"
    label_dict = None
    embed_length = 128

    para_dict = {"train_img_dir":train_img_dir,"test_img_dir":test_img_dir,"label_dict":label_dict}

    cls = Facenet(para_dict)

    model_shape = [None,112,112,3]
    
    infer_method = "inception_resnet_v1_reduction"
    loss_method = "cross_entropy"
    opti_method = "adam"
    learning_rate = 5e-4
    save_dir = "/content/drive/MyDrive/MFR_final_year_nitw/model"

    para_dict = {"model_shape":model_shape,"infer_method":infer_method,"loss_method":loss_method,
                 "opti_method":opti_method,'learning_rate':learning_rate,"save_dir":save_dir,'embed_length':embed_length}
    cls.model_init(para_dict)

    epochs = 60
    GPU_ratio = None
    
    batch_size = 48
    ratio = 0.6
    random_flip = True
    random_brightness = True
    random_crop = True
    random_angle = True
    random_noise = True

    process_dict = {"rdm_flip":random_flip,'rdm_br':random_brightness,'rdm_crop':random_crop,'rdm_angle':random_angle,
                    'rdm_noise':random_noise}
    if True in process_dict.values():
        pass
    else:
        process_dict = None
    para_dict = {'epochs':epochs, "GPU_ratio":GPU_ratio, "batch_size":batch_size,"ratio":ratio,'process_dict':process_dict}

    cls.train(para_dict)
# Out:
# WARNING:tensorflow:
# The TensorFlow contrib module will not be included in TensorFlow 2.0.
# For more information, please see:
#   * https://github.com/tensorflow/community/blob/master/rfcs/20180907-contrib-sunset.md
#   * https://github.com/tensorflow/addons
#   * https://github.com/tensorflow/io (for I/O related ops)
# If you depend on functionality not listed there, please file an issue.
#
# Tensorflow version:  1.15.2
# Tensorflow version:  1.15.2
# train path shape:(379225,), train label shape:(379225,)
# class number: 5000
# WARNING:tensorflow:From /content/inception_resnet_v1_reduction.py:323: The name tf.GraphKeys is deprecated. Please use tf.compat.v1.GraphKeys instead.
#
# INFO:tensorflow:Scale of 0 disables regularizer.
# WARNING:tensorflow:From /content/inception_resnet_v1_reduction.py:364: The name tf.variable_scope is deprecated. Please use tf.compat.v1.variable_scope instead.
#
# WARNING:tensorflow:From /tensorflow-1.15.2/python3.7/tensorflow_core/contrib/layers/python/layers/layers.py:1057: Layer.apply (from tensorflow.python.keras.engine.base_layer) is deprecated and will be removed in a future version.
# Instructions for updating:
# Please use `layer.__call__` method instead.
# Conv2d_1a_3x3 shape: (?, 55, 55, 32)
# Conv2d_2a_3x3 shape: (?, 53, 53, 32)
# Conv2d_2b_3x3 shape: (?, 53, 53, 64)
# MaxPool_3a_3x3 shape: (?, 26, 26, 64)
# Conv2d_3b_1x1 shape: (?, 26, 26, 80)
# Conv2d_4a_3x3 shape: (?, 26, 26, 96)
# Mixed_5a shape: (?, 26, 26, 96)
# Mixed_6a shape: (?, 12, 12, 416)
# Mixed_6b shape: (?, 12, 12, 416)
# Mixed_7a shape: (?, 5, 5, 864)
# Mixed_8a shape: (?, 5, 5, 864)
# Mixed_8b shape: (?, 5, 5, 864)
# WARNING:tensorflow:From /tensorflow-1.15.2/python3.7/tensorflow_core/contrib/layers/python/layers/layers.py:1634: flatten (from tensorflow.python.layers.core) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use keras.layers.flatten instead.
# WARNING:tensorflow:From /content/inception_resnet_v1_reduction.py:446: calling dropout (from tensorflow.python.ops.nn_ops) with keep_prob is deprecated and will be removed in a future version.
# Instructions for updating:
# Please use `rate` instead of `keep_prob`. Rate should be set to `rate = 1 - keep_prob`.
# pre-logit flatten shape: (?, 864)
# WARNING:tensorflow:From <ipython-input-7-8f4eb6b15991>:136: dense (from tensorflow.python.layers.core) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use keras.layers.Dense instead.
# log_path:  /content/drive/MyDrive/MFR_final_year_nitw/model/train_result_0.json
# Device mapping:
# /job:localhost/replica:0/task:0/device:XLA_CPU:0 -> device: XLA_CPU device
# /job:localhost/replica:0/task:0/device:XLA_GPU:0 -> device: XLA_GPU device
# /job:localhost/replica:0/task:0/device:GPU:0 -> device: 0, name: Tesla K80, pci bus id: 0000:00:04.0, compute capability: 3.7
#
# no previous model param can be used!
# img_quantity: 227535
# aug_enable is True, the data quantity of one epoch is doubled
